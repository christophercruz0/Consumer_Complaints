# %%
# Import dependencies
import pandas as pd
import numpy as np
pd.set_option('max_colwidth', 400)

# %%
crowdfunding_info_df = pd.read_csv('/Users/christophercruz/Documents/Consumer_Complaints/complaints uploaded.csv')
#crowdfunding_info_df.head()
new_df = crowdfunding_info_df[['Date received','Product','Sub-product','Issue','Sub-issue','Company','State','ZIP code','Consumer consent provided?','Submitted via','Date sent to company','Company response to consumer','Timely response?','Complaint ID']]
new_df.head()
# Out:
#   Date received  \
# 0      03/28/23
# 1      12/23/22
# 2      03/18/23
# 3      01/09/23
# 4      03/07/23
#
#                                                                         Product  \
# 0  Credit reporting, credit repair services, or other personal consumer reports
# 1                                                                      Mortgage
# 2  Credit reporting, credit repair services, or other personal consumer reports
# 3  Credit reporting, credit repair services, or other personal consumer reports
# 4                                                               Debt collection
#
#                                   Sub-product  \
# 0                            Credit reporting
# 1  Home equity loan or line of credit (HELOC)
# 2                            Credit reporting
# 3                            Credit reporting
# 4                                  Other debt
#
#                                                          Issue  \
# ...

# %%
new_df.to_csv("/Users/christophercruz/Documents/Consumer_Complaints/Consumer Complaint_Cleaned.csv", encoding='utf-8', index=False)
