# %%
# SQLAlchemy
import sqlalchemy
import psycopg2
import datetime as dt
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine , inspect , func
from flask import Flask

db_password = 'postgres'

# %%
# Path to sqlite
database_path = f"postgresql://postgres:{db_password}@127.0.0.1:5432/Consumer_complaints_db"

# Create an engine that can talk to the database
engine = create_engine(database_path)

# %%
# Query All Records in the the Database
#data = engine.execute("SELECT * FROM complaints")

inspector = inspect(engine)
inspector.get_table_names()
# Out:
# ['complaints']

# %%
columns = inspector.get_columns('complaints')
for c in columns:
    print(c['name'], c["type"])
# Out:
# date_received DATE
# product VARCHAR(100)
# sub_product VARCHAR(100)
# issue VARCHAR(150)
# sub_issue VARCHAR(200)
# company VARCHAR(150)
# state VARCHAR(100)
# zip_code VARCHAR(100)
# consumer_consent_provided VARCHAR(100)
# submitted_via VARCHAR(200)
# date_sent_to_company DATE
# company_response_to_consumer VARCHAR(500)
# timely_response VARCHAR(500)
# complaint_id INTEGER

# %%
engine.execute('SELECT * FROM complaints').fetchall()
# Out:
# [(datetime.date(2023, 2, 26), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Investigation took more than 30 days', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'MD', '21075', 'Consent provided', 'Web', datetime.date(2023, 2, 26), 'Closed with non-monetary relief', 'Yes', 6620309),
#  (datetime.date(2023, 2, 10), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Account status incorrect', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'CA', '95242', 'Consent provided', 'Web', datetime.date(2023, 2, 10), 'Closed with non-monetary relief', 'Yes', 6557458),
#  (datetime.date(2023, 3, 11), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Their investigation did not fix an error on your report', 'EQUIFAX, INC.', 'SC', '29153', 'None', 'Web', datetime.date(2023, 3, 11), 'In progress', 'Yes', 6680884),
#  (datetime.date(2023, 3, 13), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Their investigation did not fix an error on your report', 'Regional Management Corporation', 'AL', '36693', 'None', 'Web', datetime.date(2023, 3, 13), 'Closed with explanation', 'Yes', 6683873),
#  (datetime.date(2023, 3, 11), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Their investigation did not fix an error on your report', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'SC', '29153', 'None', 'Web', datetime.date(2023, 3, 11), 'In progress', 'Yes', 6680885),
#  (datetime.date(2023, 3, 11), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Their investigation did not fix an error on your report', 'EQUIFAX, INC.', 'RI', '02885', 'None', 'Web', datetime.date(2023, 3, 11), 'In progress', 'Yes', 6680863),
#  (datetime.date(2023, 3, 15), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Their investigation did not fix an error on your report', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'CA', '93950', 'None', 'Web', datetime.date(2023, 3, 15), 'In progress', 'Yes', 6691618),
#  (datetime.date(2023, 3, 4), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'MD', '20770', 'None', 'Web', datetime.date(2023, 3, 4), 'In progress', 'Yes', 6648595),
#  (datetime.date(2023, 2, 14), 'Mortgage', 'Conventional home mortgage', 'Trouble during payment process', 'None', 'Freedom Mortgage Company', 'FL', '32808', 'Consent not provided', 'Web', datetime.date(2023, 2, 14), 'Closed with explanation', 'Yes', 6572496),
#  (datetime.date(2023, 1, 11), 'Mortgage', 'Conventional home mortgage', 'Trouble during payment process', 'None', 'SELECT PORTFOLIO SERVICING, INC.', 'GA', '30066', 'Consent provided', 'Web', datetime.date(2023, 1, 11), 'Closed with explanation', 'Yes', 6420869),
#  (datetime.date(2023, 3, 15), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', "Credit inquiries on your report that you don't recognize", 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'KY', '40330', 'None', 'Web', datetime.date(2023, 3, 15), 'In progress', 'Yes', 6697445),
#  (datetime.date(2023, 1, 11), 'Mortgage', 'Conventional home mortgage', 'Trouble during payment process', 'None', 'RUSHMORE LOAN MANAGEMENT SERVICES LLC', 'MD', '21801', 'Consent provided', 'Web', datetime.date(2023, 1, 11), 'Closed with explanation', 'Yes', 6425515),
#  (datetime.date(2023, 2, 10), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Information belongs to someone else', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'TX', '78211', 'Consent not provided', 'Web', datetime.date(2023, 2, 10), 'Closed with non-monetary relief', 'Yes', 6558755),
#  (datetime.date(2023, 3, 13), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'AZ', '85374', 'None', 'Web', datetime.date(2023, 3, 13), 'In progress', 'Yes', 6690192),
#  (datetime.date(2023, 3, 11), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'ALLY FINANCIAL INC.', 'IL', '60617', 'Consent not provided', 'Web', datetime.date(2023, 3, 11), 'Closed with explanation', 'Yes', 6680894),
#  (datetime.date(2022, 12, 20), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Their investigation did not fix an error on your report', 'Experian Information Solutions Inc.', 'FL', '32218', 'Consent not provided', 'Web', datetime.date(2022, 12, 20), 'Closed with explanation', 'Yes', 6343005),
#  (datetime.date(2023, 2, 10), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Their investigation did not fix an error on your report', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'PA', '15001', 'Consent provided', 'Web', datetime.date(2023, 2, 10), 'Closed with non-monetary relief', 'Yes', 6557454),
#  (datetime.date(2023, 3, 13), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Information belongs to someone else', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'AZ', '85202', 'None', 'Web', datetime.date(2023, 3, 13), 'In progress', 'Yes', 6683853),
#  (datetime.date(2023, 3, 11), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Their investigation did not fix an error on your report', 'EQUIFAX, INC.', 'NJ', '07111', 'None', 'Web', datetime.date(2023, 3, 11), 'In progress', 'Yes', 6680589),
#  (datetime.date(2023, 3, 11), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Their investigation did not fix an error on your report', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'NJ', '07111', 'None', 'Web', datetime.date(2023, 3, 11), 'In progress', 'Yes', 6680590),
#  (datetime.date(2023, 3, 29), 'Money transfer, virtual currency, or money service', 'Mobile or digital wallet', 'Unauthorized transactions or other transaction problem', 'None', 'Paypal Holdings, Inc', 'VA', '24016', 'None', 'Web', datetime.date(2023, 3, 29), 'Closed with monetary relief', 'Yes', 6761059),
#  (datetime.date(2023, 3, 13), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Their investigation did not fix an error on your report', 'EQUIFAX, INC.', 'LA', '70560', 'None', 'Web', datetime.date(2023, 3, 13), 'Closed with explanation', 'Yes', 6687476),
#  (datetime.date(2023, 3, 11), 'Mortgage', 'Conventional home mortgage', 'Trouble during payment process', 'None', 'Freedom Mortgage Company', 'CA', '94960', 'Consent provided', 'Web', datetime.date(2023, 3, 11), 'Closed with explanation', 'Yes', 6680592),
#  (datetime.date(2023, 3, 19), 'Debt collection', 'Other debt', 'Written notification about debt', "Didn't receive enough information to verify debt", 'CAINE & WEINER COMPANY, INC.', 'FL', '33617', 'None', 'Web', datetime.date(2023, 3, 19), 'Closed with explanation', 'Yes', 6719007),
#  (datetime.date(2023, 3, 12), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'EQUIFAX, INC.', 'PA', '19151', 'Other', 'Web', datetime.date(2023, 3, 12), 'In progress', 'Yes', 6683212),
#  (datetime.date(2023, 2, 14), 'Mortgage', 'Conventional home mortgage', 'Trouble during payment process', 'None', 'LoanCare, LLC', 'TX', '75115', 'Consent not provided', 'Web', datetime.date(2023, 2, 14), 'Closed with explanation', 'Yes', 6572393),
#  (datetime.date(2023, 2, 10), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Was not notified of investigation status or results', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'NY', '11219', 'Consent provided', 'Web', datetime.date(2023, 2, 10), 'Closed with non-monetary relief', 'Yes', 6550560),
#  (datetime.date(2022, 12, 20), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Their investigation did not fix an error on your report', 'Experian Information Solutions Inc.', 'FL', '33467', None, 'Phone', datetime.date(2022, 12, 20), 'Closed with explanation', 'Yes', 6343223),
#  (datetime.date(2023, 3, 15), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Information belongs to someone else', 'EQUIFAX, INC.', 'NY', '11213', 'None', 'Web', datetime.date(2023, 3, 15), 'In progress', 'Yes', 6697772),
#  (datetime.date(2023, 3, 11), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Investigation took more than 30 days', 'EQUIFAX, INC.', 'TX', '75115', 'None', 'Web', datetime.date(2023, 3, 11), 'Closed with explanation', 'Yes', 6680679),
#  (datetime.date(2023, 3, 6), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'Experian Information Solutions Inc.', 'AL', '36105', 'None', 'Web', datetime.date(2023, 3, 6), 'In progress', 'Yes', 6650243),
#  (datetime.date(2023, 3, 7), 'Checking or savings account', 'Other banking product or service', 'Problem with a lender or other company charging your account', 'Money was taken from your account on the wrong day or for the wrong amount', 'WELLS FARGO & COMPANY', 'GA', '30047', 'Consent provided', 'Web', datetime.date(2023, 3, 7), 'Closed with explanation', 'Yes', 6653034),
#  (datetime.date(2022, 6, 30), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Information belongs to someone else', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'NY', '10952', 'Consent provided', 'Web', datetime.date(2022, 6, 30), 'Closed with non-monetary relief', 'Yes', 5723032),
#  (datetime.date(2022, 12, 20), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'Experian Information Solutions Inc.', 'FL', '33150', 'Consent provided', 'Web', datetime.date(2022, 12, 20), 'Closed with non-monetary relief', 'Yes', 6342540),
#  (datetime.date(2023, 3, 11), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'Experian Information Solutions Inc.', 'GA', '30168', 'None', 'Web', datetime.date(2023, 3, 11), 'In progress', 'Yes', 6680763),
#  (datetime.date(2023, 1, 11), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'NY', '14303', 'Consent provided', 'Web', datetime.date(2023, 1, 11), 'Closed with explanation', 'Yes', 6428810),
#  (datetime.date(2023, 1, 11), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', "Credit inquiries on your report that you don't recognize", 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'TX', '75056', 'Consent not provided', 'Web', datetime.date(2023, 1, 11), 'Closed with non-monetary relief', 'Yes', 6419014),
#  (datetime.date(2023, 3, 13), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', "Credit inquiries on your report that you don't recognize", 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'NV', '89139', 'None', 'Web', datetime.date(2023, 3, 13), 'In progress', 'Yes', 6684063),
#  (datetime.date(2023, 2, 14), 'Credit card or prepaid card', 'General-purpose credit card or charge card', "Problem with a credit reporting company's investigation into an existing problem", 'Was not notified of investigation status or results', 'Experian Information Solutions Inc.', 'IL', '61616', 'None', 'Web', datetime.date(2023, 2, 14), 'In progress', 'Yes', 6570695),
#  (datetime.date(2023, 3, 5), 'Debt collection', 'Other debt', 'Attempts to collect debt not owed', 'Debt is not yours', 'ENCORE CAPITAL GROUP INC.', 'FL', '33605', 'None', 'Web', datetime.date(2023, 3, 5), 'Closed with non-monetary relief', 'Yes', 6650765),
#  (datetime.date(2023, 3, 14), 'Credit card or prepaid card', 'General-purpose credit card or charge card', 'Getting a credit card', 'Card opened as result of identity theft or fraud', 'BANK OF AMERICA, NATIONAL ASSOCIATION', 'ID', '83204', 'None', 'Web', datetime.date(2023, 3, 14), 'In progress', 'Yes', 6695219),
#  (datetime.date(2023, 2, 14), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Account information incorrect', 'Experian Information Solutions Inc.', 'CA', '90808', 'None', 'Web', datetime.date(2023, 2, 14), 'In progress', 'Yes', 6565007),
#  (datetime.date(2022, 12, 21), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'Experian Information Solutions Inc.', 'GA', '30331', 'Consent not provided', 'Web', datetime.date(2022, 12, 21), 'Closed with explanation', 'Yes', 6341105),
#  (datetime.date(2022, 12, 20), 'Credit card or prepaid card', 'General-purpose credit card or charge card', 'Problem with a purchase shown on your statement', "Credit card company isn't resolving a dispute about a purchase on your statement", 'AMERICAN EXPRESS COMPANY', 'IL', '60169', 'None', 'Web Referral', datetime.date(2022, 12, 22), 'Closed with monetary relief', 'Yes', 6354050),
#  (datetime.date(2023, 3, 13), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'FL', '33428', 'None', 'Web', datetime.date(2023, 3, 13), 'In progress', 'Yes', 6690249),
#  (datetime.date(2022, 6, 27), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'Experian Information Solutions Inc.', 'TX', '75901', 'Consent not provided', 'Web', datetime.date(2022, 6, 27), 'Closed with non-monetary relief', 'Yes', 5713525),
#  (datetime.date(2023, 3, 24), 'Debt collection', 'Credit card debt', 'Attempts to collect debt not owed', 'Debt was result of identity theft', 'Blitt and Gaines, P.C.', 'IL', '60609', 'None', 'Web', datetime.date(2023, 3, 24), 'Closed with explanation', 'Yes', 6746459),
#  (datetime.date(2023, 3, 8), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Account status incorrect', 'Experian Information Solutions Inc.', 'VA', '23669', 'None', 'Web', datetime.date(2023, 3, 8), 'In progress', 'Yes', 6667392),
#  (datetime.date(2023, 3, 11), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'EQUIFAX, INC.', 'IL', '60803', 'None', 'Web', datetime.date(2023, 3, 11), 'Closed with explanation', 'Yes', 6680908),
#  (datetime.date(2023, 2, 10), 'Debt collection', 'Other debt', 'Attempts to collect debt not owed', 'Debt was result of identity theft', 'Spring Oaks Capital, LLC', 'VA', '23223', 'Consent provided', 'Web', datetime.date(2023, 2, 10), 'Closed with explanation', 'Yes', 6550689),
#  (datetime.date(2022, 12, 29), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Was not notified of investigation status or results', 'EQUIFAX, INC.', 'FL', '33647', None, 'Phone', datetime.date(2022, 12, 29), 'Closed with explanation', 'Yes', 6373538),
#  (datetime.date(2022, 11, 16), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Their investigation did not fix an error on your report', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'GA', '31601', 'Consent not provided', 'Web', datetime.date(2022, 11, 17), 'Closed with non-monetary relief', 'Yes', 6210887),
#  (datetime.date(2023, 3, 11), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', '1st Franklin Financial Corporation', 'MS', '39305', 'None', 'Web', datetime.date(2023, 3, 11), 'Closed with explanation', 'Yes', 6680802),
#  (datetime.date(2023, 3, 24), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'PA', '19143', 'None', 'Web', datetime.date(2023, 3, 24), 'In progress', 'Yes', 6746109),
#  (datetime.date(2023, 2, 14), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'Experian Information Solutions Inc.', 'TN', '37042', 'None', 'Web', datetime.date(2023, 2, 14), 'In progress', 'Yes', 6564924),
#  (datetime.date(2023, 1, 13), 'Credit card or prepaid card', 'General-purpose credit card or charge card', 'Problem with a purchase shown on your statement', 'Card was charged for something you did not purchase with the card', 'CAPITAL ONE FINANCIAL CORPORATION', 'FL', '32258', 'Consent provided', 'Web', datetime.date(2023, 1, 13), 'Closed with explanation', 'Yes', 6430644),
#  (datetime.date(2022, 12, 21), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Personal information incorrect', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'PA', '15129', 'Consent not provided', 'Web', datetime.date(2022, 12, 21), 'Closed with explanation', 'Yes', 6341177),
#  (datetime.date(2023, 2, 14), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'Experian Information Solutions Inc.', 'NY', '11419', 'Consent provided', 'Web', datetime.date(2023, 2, 14), 'Closed with explanation', 'Yes', 6564731),
#  (datetime.date(2023, 3, 8), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'Experian Information Solutions Inc.', 'MS', '39341', 'None', 'Web', datetime.date(2023, 3, 8), 'In progress', 'Yes', 6667410),
#  (datetime.date(2022, 12, 21), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Information belongs to someone else', 'BANK OF AMERICA, NATIONAL ASSOCIATION', 'NV', '89183', None, 'Referral', datetime.date(2022, 12, 22), 'Closed with explanation', 'Yes', 6354161),
#  (datetime.date(2023, 3, 15), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'Experian Information Solutions Inc.', 'TX', '77346', 'None', 'Web', datetime.date(2023, 3, 15), 'In progress', 'Yes', 6702929),
#  (datetime.date(2023, 3, 12), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Information belongs to someone else', 'EQUIFAX, INC.', 'FL', '32738', 'None', 'Web', datetime.date(2023, 3, 12), 'In progress', 'Yes', 6682956),
#  (datetime.date(2022, 9, 26), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'Experian Information Solutions Inc.', 'TN', '37210', 'Consent not provided', 'Web', datetime.date(2022, 9, 26), 'Closed with explanation', 'Yes', 6021154),
#  (datetime.date(2023, 3, 13), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'HYUNDAI CAPITAL AMERICA', 'PA', '19335', 'Consent not provided', 'Web', datetime.date(2023, 3, 13), 'Closed with explanation', 'Yes', 6690028),
#  (datetime.date(2022, 12, 21), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'CITIBANK, N.A.', 'CA', '90650', 'Consent not provided', 'Web', datetime.date(2022, 12, 21), 'Closed with explanation', 'Yes', 6349247),
#  (datetime.date(2022, 11, 24), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'Experian Information Solutions Inc.', 'MI', '48021', 'Consent not provided', 'Web', datetime.date(2022, 11, 24), 'Closed with explanation', 'Yes', 6240082),
#  (datetime.date(2023, 3, 11), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'CO', '80209', 'None', 'Web', datetime.date(2023, 3, 11), 'In progress', 'Yes', 6680918),
#  (datetime.date(2023, 3, 11), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'MIDFIRST BANK', 'IL', '60617', 'Consent not provided', 'Web', datetime.date(2023, 3, 11), 'Closed with explanation', 'Yes', 6680967),
#  (datetime.date(2022, 6, 27), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', "Credit inquiries on your report that you don't recognize", 'EQUIFAX, INC.', 'CA', '92659', 'Consent provided', 'Web', datetime.date(2022, 6, 27), 'Closed with explanation', 'Yes', 5713957),
#  (datetime.date(2022, 12, 21), 'Checking or savings account', 'Checking account', 'Opening an account', "Didn't receive terms that were advertised", 'U.S. BANCORP', 'CA', '91765', 'Consent not provided', 'Web', datetime.date(2022, 12, 21), 'Closed with explanation', 'Yes', 6349623),
#  (datetime.date(2023, 2, 15), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Account status incorrect', 'Experian Information Solutions Inc.', 'GA', '30134', 'Other', 'Web', datetime.date(2023, 2, 15), 'In progress', 'Yes', 6577813),
#  (datetime.date(2023, 3, 11), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'EQUIFAX, INC.', 'NY', '11575', 'None', 'Web', datetime.date(2023, 3, 11), 'Closed with explanation', 'Yes', 6680794),
#  (datetime.date(2023, 3, 13), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Account information incorrect', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'NY', '11580', 'None', 'Web', datetime.date(2023, 3, 13), 'In progress', 'Yes', 6688856),
#  (datetime.date(2023, 3, 4), 'Checking or savings account', 'Checking account', 'Managing an account', 'Deposits and withdrawals', 'Kikoff Inc.', 'NY', '11237', 'Consent provided', 'Web', datetime.date(2023, 3, 4), 'Closed with explanation', 'Yes', 6648662),
#  (datetime.date(2023, 3, 13), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Information belongs to someone else', 'EQUIFAX, INC.', 'IL', '60643', 'None', 'Web', datetime.date(2023, 3, 13), 'In progress', 'Yes', 6684091),
#  (datetime.date(2022, 11, 24), 'Money transfer, virtual currency, or money service', 'Domestic (US) money transfer', 'Fraud or scam', 'None', 'BANK OF AMERICA, NATIONAL ASSOCIATION', 'NY', '10025', 'Consent not provided', 'Web', datetime.date(2022, 11, 24), 'Closed with explanation', 'Yes', 6241612),
#  (datetime.date(2023, 1, 11), 'Checking or savings account', 'Checking account', 'Opening an account', 'Account opened as a result of fraud', 'TD BANK US HOLDING COMPANY', 'NJ', '07018', 'Consent provided', 'Web', datetime.date(2023, 1, 11), 'Closed with explanation', 'Yes', 6419024),
#  (datetime.date(2023, 3, 11), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Account status incorrect', 'Radius Global Solutions LLC', 'NY', '12866', 'None', 'Web', datetime.date(2023, 3, 11), 'In progress', 'Yes', 6680966),
#  (datetime.date(2022, 12, 29), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Their investigation did not fix an error on your report', 'EQUIFAX, INC.', 'CA', '95205', 'Consent provided', 'Web', datetime.date(2022, 12, 29), 'Closed with explanation', 'Yes', 6370253),
#  (datetime.date(2023, 3, 7), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'Experian Information Solutions Inc.', 'CA', '94132', 'None', 'Web', datetime.date(2023, 3, 7), 'In progress', 'Yes', 6662940),
#  (datetime.date(2022, 12, 19), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Their investigation did not fix an error on your report', 'Experian Information Solutions Inc.', 'GA', '30274', 'Consent provided', 'Web', datetime.date(2022, 12, 19), 'Closed with non-monetary relief', 'Yes', 6338873),
#  (datetime.date(2023, 2, 26), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', "Credit inquiries on your report that you don't recognize", 'Experian Information Solutions Inc.', 'NC', '27407', 'Consent not provided', 'Web', datetime.date(2023, 2, 26), 'Closed with non-monetary relief', 'Yes', 6615765),
#  (datetime.date(2023, 3, 8), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Their investigation did not fix an error on your report', 'Experian Information Solutions Inc.', 'NJ', '08066', None, 'Phone', datetime.date(2023, 3, 10), 'In progress', 'Yes', 6667598),
#  (datetime.date(2023, 3, 5), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Information belongs to someone else', 'Ability Recovery Services, LLC', 'CO', '80111', 'Consent provided', 'Web', datetime.date(2023, 3, 5), 'Closed with explanation', 'Yes', 6650788),
#  (datetime.date(2023, 3, 7), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Investigation took more than 30 days', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'CA', '92883', 'None', 'Web', datetime.date(2023, 3, 7), 'In progress', 'Yes', 6663236),
#  (datetime.date(2023, 1, 11), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Information belongs to someone else', 'Experian Information Solutions Inc.', 'TX', '77027', 'Consent not provided', 'Web', datetime.date(2023, 1, 11), 'Closed with explanation', 'Yes', 6419345),
#  (datetime.date(2023, 2, 9), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Information belongs to someone else', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'TX', '75043', 'Consent not provided', 'Web', datetime.date(2023, 2, 9), 'Closed with non-monetary relief', 'Yes', 6554289),
#  (datetime.date(2023, 2, 15), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'None', 'None', 'Consent not provided', 'Web', datetime.date(2023, 2, 15), 'Closed with non-monetary relief', 'Yes', 6574948),
#  (datetime.date(2023, 2, 15), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Their investigation did not fix an error on your report', 'Experian Information Solutions Inc.', 'NC', '28801', 'None', 'Web', datetime.date(2023, 2, 15), 'In progress', 'Yes', 6575063),
#  (datetime.date(2023, 2, 15), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Account information incorrect', 'EQUIFAX, INC.', 'GA', '31520', 'None', 'Web', datetime.date(2023, 2, 15), 'Closed with explanation', 'Yes', 6575008),
#  (datetime.date(2023, 1, 11), 'Mortgage', 'Conventional home mortgage', 'Trouble during payment process', 'None', 'Selene Holdings LLC', 'FL', '33189', 'Consent provided', 'Web', datetime.date(2023, 1, 12), 'Closed with explanation', 'Yes', 6425719),
#  (datetime.date(2023, 2, 26), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Their investigation did not fix an error on your report', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'GA', '30066', 'Consent provided', 'Web', datetime.date(2023, 2, 26), 'Closed with non-monetary relief', 'Yes', 6618248),
#  (datetime.date(2023, 2, 15), 'Mortgage', 'Home equity loan or line of credit (HELOC)', 'Trouble during payment process', 'None', 'BANK OF AMERICA, NATIONAL ASSOCIATION', 'AZ', '85310', 'None', 'Web', datetime.date(2023, 2, 16), 'In progress', 'Yes', 6574641),
#  (datetime.date(2022, 12, 21), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Personal information incorrect', 'EQUIFAX, INC.', 'MD', '21224', 'Consent not provided', 'Web', datetime.date(2022, 12, 21), 'Closed with explanation', 'Yes', 6349616),
#  (datetime.date(2023, 3, 5), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'SANTANDER HOLDINGS USA, INC.', 'SC', '29061', 'None', 'Web', datetime.date(2023, 3, 5), 'Closed with explanation', 'Yes', 6650508),
#  (datetime.date(2023, 2, 26), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'TX', '75224', 'Consent provided', 'Web', datetime.date(2023, 2, 26), 'Closed with non-monetary relief', 'Yes', 6617982),
#  (datetime.date(2023, 2, 9), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Account information incorrect', 'EQUIFAX, INC.', 'GA', '30318', 'Consent provided', 'Web', datetime.date(2023, 2, 9), 'Closed with explanation', 'Yes', 6551835),
#  (datetime.date(2023, 3, 6), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'Experian Information Solutions Inc.', 'IL', '60624', 'None', 'Web', datetime.date(2023, 3, 6), 'In progress', 'Yes', 6650006),
#  (datetime.date(2022, 9, 26), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Account status incorrect', 'Experian Information Solutions Inc.', 'NY', '11691', 'Consent provided', 'Web', datetime.date(2022, 9, 26), 'Closed with explanation', 'Yes', 6018452),
#  (datetime.date(2023, 3, 6), 'Debt collection', 'I do not know', 'Attempts to collect debt not owed', 'Debt is not yours', 'W&A Intermediate Co., LLC', 'TX', '79731', 'None', 'Web', datetime.date(2023, 3, 6), 'In progress', 'Yes', 6650261),
#  (datetime.date(2023, 3, 8), 'Checking or savings account', 'Checking account', 'Opening an account', "Didn't receive terms that were advertised", 'BANK OF AMERICA, NATIONAL ASSOCIATION', 'NY', '11101', 'Consent provided', 'Web', datetime.date(2023, 3, 8), 'Closed with monetary relief', 'Yes', 6667401),
#  (datetime.date(2023, 3, 4), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'Experian Information Solutions Inc.', 'MS', '39232', 'None', 'Web', datetime.date(2023, 3, 4), 'In progress', 'Yes', 6648691),
#  (datetime.date(2023, 3, 6), 'Debt collection', 'Other debt', 'Attempts to collect debt not owed', 'Debt is not yours', 'Aldous & Associates, PLLC', 'UT', '84020', None, 'Phone', datetime.date(2023, 3, 6), 'Closed with explanation', 'Yes', 6654321),
#  (datetime.date(2023, 1, 4), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Account information incorrect', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'MO', '63011', 'Consent not provided', 'Web', datetime.date(2023, 1, 4), 'Closed with explanation', 'Yes', 6389623),
#  (datetime.date(2023, 3, 4), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'CITIBANK, N.A.', 'CT', '06320', 'Consent provided', 'Web', datetime.date(2023, 3, 4), 'Closed with explanation', 'Yes', 6648613),
#  (datetime.date(2022, 6, 27), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', "Credit inquiries on your report that you don't recognize", 'EQUIFAX, INC.', 'TX', '76148', 'Consent provided', 'Web', datetime.date(2022, 6, 27), 'Closed with explanation', 'Yes', 5714043),
#  (datetime.date(2022, 12, 21), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Information belongs to someone else', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'CA', '90278', 'Consent provided', 'Web', datetime.date(2022, 12, 21), 'Closed with non-monetary relief', 'Yes', 6341483),
#  (datetime.date(2023, 3, 11), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', "Credit inquiries on your report that you don't recognize", 'Experian Information Solutions Inc.', 'GA', '30004', 'None', 'Web', datetime.date(2023, 3, 11), 'In progress', 'Yes', 6680727),
#  (datetime.date(2023, 3, 13), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'Experian Information Solutions Inc.', 'VA', '22192', 'None', 'Web', datetime.date(2023, 3, 13), 'In progress', 'Yes', 6689910),
#  (datetime.date(2023, 2, 15), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Information belongs to someone else', 'Experian Information Solutions Inc.', 'VA', '24501', 'None', 'Web', datetime.date(2023, 2, 15), 'In progress', 'Yes', 6575260),
#  (datetime.date(2022, 7, 1), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Their investigation did not fix an error on your report', 'Experian Information Solutions Inc.', 'FL', '32801', 'Consent not provided', 'Web', datetime.date(2022, 7, 1), 'Closed with non-monetary relief', 'Yes', 5728000),
#  (datetime.date(2022, 9, 26), 'Vehicle loan or lease', 'Loan', 'Problems at the end of the loan or lease', 'Unable to receive car title or other problem after the loan is paid off', 'ALLY FINANCIAL INC.', 'NJ', '08226', 'None', 'Web Referral', datetime.date(2022, 9, 27), 'Closed with explanation', 'Yes', 6026217),
#  (datetime.date(2023, 1, 11), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Account status incorrect', 'Experian Information Solutions Inc.', 'FL', '33610', 'Consent provided', 'Web', datetime.date(2023, 1, 11), 'Closed with non-monetary relief', 'Yes', 6421073),
#  (datetime.date(2023, 3, 13), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'EQUIFAX, INC.', 'CA', '92105', 'None', 'Web', datetime.date(2023, 3, 13), 'In progress', 'Yes', 6683606),
#  (datetime.date(2023, 2, 23), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', "Credit inquiries on your report that you don't recognize", 'EQUIFAX, INC.', 'OH', '44212', 'None', 'Web', datetime.date(2023, 2, 23), 'Closed with explanation', 'Yes', 6607690),
#  (datetime.date(2022, 12, 21), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Information belongs to someone else', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'TX', '77535', None, 'Postal mail', datetime.date(2022, 12, 21), 'Closed with non-monetary relief', 'Yes', 6345858),
#  (datetime.date(2023, 3, 6), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Account information incorrect', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'FL', '33764', 'None', 'Web', datetime.date(2023, 3, 6), 'In progress', 'Yes', 6649998),
#  (datetime.date(2023, 3, 4), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Their investigation did not fix an error on your report', 'Experian Information Solutions Inc.', 'MA', '02121', 'None', 'Web', datetime.date(2023, 3, 4), 'In progress', 'Yes', 6648673),
#  (datetime.date(2023, 3, 5), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Personal information incorrect', 'Experian Information Solutions Inc.', 'NY', '10977', 'Consent not provided', 'Web', datetime.date(2023, 3, 5), 'Closed with explanation', 'Yes', 6650567),
#  (datetime.date(2022, 12, 21), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Account status incorrect', 'Experian Information Solutions Inc.', 'GA', '30214', 'Consent not provided', 'Web', datetime.date(2022, 12, 21), 'Closed with explanation', 'Yes', 6345857),
#  (datetime.date(2023, 3, 6), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', "Credit inquiries on your report that you don't recognize", 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'MD', '21044', 'Other', 'Web', datetime.date(2023, 3, 6), 'In progress', 'Yes', 6653423),
#  (datetime.date(2023, 2, 8), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Public record information inaccurate', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'GA', '30082', 'Consent provided', 'Web', datetime.date(2023, 2, 8), 'Closed with non-monetary relief', 'Yes', 6546836),
#  (datetime.date(2023, 2, 16), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Information belongs to someone else', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'DE', '19808', 'Consent not provided', 'Web', datetime.date(2023, 2, 16), 'Closed with non-monetary relief', 'Yes', 6580690),
#  (datetime.date(2023, 2, 8), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', "Credit inquiries on your report that you don't recognize", 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'WI', '53209', 'Consent not provided', 'Web', datetime.date(2023, 2, 8), 'Closed with non-monetary relief', 'Yes', 6546950),
#  (datetime.date(2023, 2, 13), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Their investigation did not fix an error on your report', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'NV', '89139', 'Consent provided', 'Web', datetime.date(2023, 2, 13), 'Closed with non-monetary relief', 'Yes', 6565100),
#  (datetime.date(2023, 3, 4), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Account information incorrect', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'CA', '95205', 'None', 'Web', datetime.date(2023, 3, 4), 'In progress', 'Yes', 6648358),
#  (datetime.date(2023, 1, 2), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'EQUIFAX, INC.', 'LA', '71115', 'Consent not provided', 'Web', datetime.date(2023, 1, 2), 'Closed with explanation', 'Yes', 6383585),
#  (datetime.date(2023, 3, 6), 'Mortgage', 'Conventional home mortgage', 'Trouble during payment process', 'None', 'Specialized Loan Servicing Holdings LLC', 'MD', '20685', 'Consent provided', 'Web', datetime.date(2023, 3, 6), 'Closed with explanation', 'Yes', 6649801),
#  (datetime.date(2023, 2, 8), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Investigation took more than 30 days', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'GA', '30318', 'Consent not provided', 'Web', datetime.date(2023, 2, 8), 'Closed with non-monetary relief', 'Yes', 6547278),
#  (datetime.date(2023, 1, 11), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Information belongs to someone else', 'EQUIFAX, INC.', 'NY', '11233', 'Consent not provided', 'Web', datetime.date(2023, 1, 11), 'Closed with explanation', 'Yes', 6425975),
#  (datetime.date(2023, 1, 13), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'EQUIFAX, INC.', 'IL', '60443', 'Consent not provided', 'Web', datetime.date(2023, 1, 13), 'Closed with explanation', 'Yes', 6439879),
#  (datetime.date(2022, 12, 21), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Their investigation did not fix an error on your report', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'MS', '38671', 'Consent provided', 'Web', datetime.date(2022, 12, 21), 'Closed with explanation', 'Yes', 6349312),
#  (datetime.date(2022, 6, 27), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'CA', '93301', 'Consent not provided', 'Web', datetime.date(2022, 6, 27), 'Closed with non-monetary relief', 'Yes', 5713728),
#  (datetime.date(2023, 3, 4), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Their investigation did not fix an error on your report', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'FL', '34951', 'None', 'Web', datetime.date(2023, 3, 4), 'In progress', 'Yes', 6648230),
#  (datetime.date(2023, 3, 7), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'EQUIFAX, INC.', 'NJ', '08104', 'None', 'Web', datetime.date(2023, 3, 7), 'In progress', 'Yes', 6653105),
#  (datetime.date(2023, 3, 13), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Their investigation did not fix an error on your report', 'EQUIFAX, INC.', 'TX', '78240', 'None', 'Web', datetime.date(2023, 3, 13), 'In progress', 'Yes', 6683436),
# ...
#  (datetime.date(2023, 2, 14), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Investigation took more than 30 days', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'FL', '34474', None, 'Phone', datetime.date(2023, 2, 14), 'Closed with non-monetary relief', 'Yes', 6572536),
#  (datetime.date(2022, 12, 21), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Their investigation did not fix an error on your report', 'EQUIFAX, INC.', 'GA', '30350', 'Consent provided', 'Web', datetime.date(2022, 12, 21), 'Closed with explanation', 'Yes', 6349194),
#  (datetime.date(2023, 3, 13), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'FL', '32812', 'None', 'Web', datetime.date(2023, 3, 13), 'In progress', 'Yes', 6690239),
#  (datetime.date(2022, 12, 21), 'Checking or savings account', 'Checking account', 'Managing an account', 'Problem accessing account', 'Chime Financial Inc', 'FL', '32258', 'Consent provided', 'Web', datetime.date(2022, 12, 21), 'Closed with explanation', 'Yes', 6349203),
#  (datetime.date(2022, 12, 21), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Their investigation did not fix an error on your report', 'EQUIFAX, INC.', 'IL', '62208', 'Consent not provided', 'Web', datetime.date(2022, 12, 21), 'Closed with explanation', 'Yes', 6349443),
#  (datetime.date(2023, 3, 27), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Information belongs to someone else', 'Experian Information Solutions Inc.', 'NC', '28215', 'None', 'Web', datetime.date(2023, 3, 27), 'In progress', 'Yes', 6750288),
#  (datetime.date(2023, 3, 31), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Investigation took more than 30 days', 'Experian Information Solutions Inc.', 'PA', '15108', 'None', 'Web', datetime.date(2023, 3, 31), 'In progress', 'Yes', 6778210),
#  (datetime.date(2023, 2, 13), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Account information incorrect', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'FL', '34711', 'Consent not provided', 'Web', datetime.date(2023, 2, 13), 'Closed with non-monetary relief', 'Yes', 6566465),
#  (datetime.date(2022, 6, 27), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Information belongs to someone else', 'Experian Information Solutions Inc.', 'NY', '11213', 'Consent provided', 'Web', datetime.date(2022, 6, 27), 'Closed with non-monetary relief', 'Yes', 5711152),
#  (datetime.date(2023, 2, 14), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Their investigation did not fix an error on your report', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'PA', '19013', 'Consent provided', 'Web', datetime.date(2023, 2, 14), 'Closed with non-monetary relief', 'Yes', 6573236),
#  (datetime.date(2023, 2, 14), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'FL', '32746', 'Consent provided', 'Web', datetime.date(2023, 2, 14), 'Closed with non-monetary relief', 'Yes', 6573149),
#  (datetime.date(2022, 9, 26), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Difficulty submitting a dispute or getting information about a dispute over the phone', 'Experian Information Solutions Inc.', 'TN', '38127', 'Consent provided', 'Web', datetime.date(2022, 9, 26), 'Closed with non-monetary relief', 'Yes', 6014832),
#  (datetime.date(2023, 1, 10), 'Credit card or prepaid card', 'General-purpose credit card or charge card', 'Improper use of your report', 'Reporting company used your report improperly', 'JPMORGAN CHASE & CO.', 'MN', '55311', 'Consent provided', 'Web', datetime.date(2023, 1, 10), 'Closed with explanation', 'Yes', 6418969),
#  (datetime.date(2022, 12, 21), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Their investigation did not fix an error on your report', 'EQUIFAX, INC.', 'GA', '30021', 'Consent not provided', 'Web', datetime.date(2022, 12, 21), 'Closed with explanation', 'Yes', 6350381),
#  (datetime.date(2023, 1, 10), 'Debt collection', 'Other debt', 'Attempts to collect debt not owed', 'Debt was result of identity theft', 'Unifin Inc.', 'CA', '95747', 'Consent not provided', 'Web', datetime.date(2023, 1, 10), 'Closed with explanation', 'Yes', 6424468),
#  (datetime.date(2023, 3, 13), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Information belongs to someone else', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'NV', '89145', 'None', 'Web', datetime.date(2023, 3, 13), 'In progress', 'Yes', 6688692),
#  (datetime.date(2022, 9, 25), 'Vehicle loan or lease', 'Lease', 'Managing the loan or lease', 'Problem with fees charged', 'U.S. BANCORP', 'WY', '82001', 'Consent provided', 'Web', datetime.date(2022, 9, 25), 'Closed with explanation', 'Yes', 6019406),
#  (datetime.date(2023, 3, 7), 'Payday loan, title loan, or personal loan', 'Personal line of credit', 'Getting a line of credit', 'None', 'WELLS FARGO & COMPANY', 'MN', '55411', None, 'Phone', datetime.date(2023, 3, 7), 'In progress', 'Yes', 6661265),
#  (datetime.date(2023, 3, 14), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Their investigation did not fix an error on your report', 'Experian Information Solutions Inc.', 'CA', '90037', 'None', 'Web', datetime.date(2023, 3, 14), 'In progress', 'Yes', 6696170),
#  (datetime.date(2023, 2, 2), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Personal information incorrect', 'Experian Information Solutions Inc.', 'TX', '75214', 'Consent provided', 'Web', datetime.date(2023, 2, 2), 'Closed with non-monetary relief', 'Yes', 6520215),
#  (datetime.date(2022, 12, 21), 'Checking or savings account', 'Other banking product or service', 'Managing an account', 'Deposits and withdrawals', 'SYNCHRONY FINANCIAL', 'HI', '96740', 'Consent provided', 'Web', datetime.date(2023, 1, 12), 'Closed with explanation', 'Yes', 6349298),
#  (datetime.date(2023, 4, 4), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Their investigation did not fix an error on your report', 'EQUIFAX, INC.', 'FL', '33068', 'None', 'Web', datetime.date(2023, 4, 4), 'In progress', 'Yes', 6794982),
#  (datetime.date(2023, 1, 23), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Problem with personal statement of dispute', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'PA', '16105', 'Consent not provided', 'Web', datetime.date(2023, 1, 23), 'Closed with explanation', 'Yes', 6470457),
#  (datetime.date(2022, 12, 21), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'PA', '15213', 'Consent not provided', 'Web', datetime.date(2022, 12, 21), 'Closed with non-monetary relief', 'Yes', 6346508),
#  (datetime.date(2023, 3, 6), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'EQUIFAX, INC.', 'NC', '28504', 'None', 'Web', datetime.date(2023, 3, 6), 'In progress', 'Yes', 6649684),
#  (datetime.date(2022, 12, 21), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Information belongs to someone else', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'MN', '55431', 'Other', 'Web', datetime.date(2022, 12, 21), 'Closed with non-monetary relief', 'Yes', 6346746),
#  (datetime.date(2023, 3, 6), 'Checking or savings account', 'Checking account', 'Managing an account', 'Deposits and withdrawals', 'CAPITAL ONE FINANCIAL CORPORATION', 'TX', '77073', 'None', 'Web', datetime.date(2023, 3, 6), 'In progress', 'Yes', 6656164),
#  (datetime.date(2022, 12, 21), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Information belongs to someone else', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'MS', '39520', 'Consent not provided', 'Web', datetime.date(2022, 12, 21), 'Closed with non-monetary relief', 'Yes', 6341149),
#  (datetime.date(2023, 3, 21), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Information belongs to someone else', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'MS', '39702', 'None', 'Web', datetime.date(2023, 3, 21), 'In progress', 'Yes', 6724068),
#  (datetime.date(2023, 3, 19), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'EQUIFAX, INC.', 'TX', '75042', 'None', 'Web', datetime.date(2023, 3, 19), 'In progress', 'Yes', 6719901),
#  (datetime.date(2023, 3, 4), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Information belongs to someone else', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'FL', '32835', 'None', 'Web', datetime.date(2023, 3, 4), 'In progress', 'Yes', 6647734),
#  (datetime.date(2023, 3, 13), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Their investigation did not fix an error on your report', 'EQUIFAX, INC.', 'MI', '48505', 'None', 'Web', datetime.date(2023, 3, 13), 'In progress', 'Yes', 6687632),
#  (datetime.date(2022, 9, 26), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Account information incorrect', 'Experian Information Solutions Inc.', 'NY', '10459', 'Consent not provided', 'Web', datetime.date(2022, 9, 26), 'Closed with non-monetary relief', 'Yes', 6014809),
#  (datetime.date(2023, 3, 20), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'EQUIFAX, INC.', 'IN', '46122', 'None', 'Web', datetime.date(2023, 3, 20), 'In progress', 'Yes', 6721509),
#  (datetime.date(2023, 3, 7), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'EQUIFAX, INC.', 'TX', '78717', 'None', 'Web', datetime.date(2023, 3, 7), 'In progress', 'Yes', 6662348),
#  (datetime.date(2022, 12, 22), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'IL', '60616', 'Consent provided', 'Web', datetime.date(2022, 12, 22), 'Closed with non-monetary relief', 'Yes', 6347348),
#  (datetime.date(2023, 3, 15), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Their investigation did not fix an error on your report', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'LA', '70115', 'None', 'Web', datetime.date(2023, 3, 15), 'In progress', 'Yes', 6702235),
#  (datetime.date(2023, 2, 13), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Account status incorrect', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'TX', '75010', 'Other', 'Web', datetime.date(2023, 2, 13), 'Closed with non-monetary relief', 'Yes', 6567934),
#  (datetime.date(2023, 3, 15), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Information belongs to someone else', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'VA', '22307', 'None', 'Web', datetime.date(2023, 3, 16), 'In progress', 'Yes', 6698561),
#  (datetime.date(2023, 3, 15), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Information belongs to someone else', 'Experian Information Solutions Inc.', 'SC', '29016', 'None', 'Web', datetime.date(2023, 3, 15), 'In progress', 'Yes', 6699269),
#  (datetime.date(2023, 1, 18), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Information belongs to someone else', 'EQUIFAX, INC.', 'NY', '10472', 'Consent not provided', 'Web', datetime.date(2023, 1, 18), 'Closed with explanation', 'Yes', 6450246),
#  (datetime.date(2023, 2, 15), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Information belongs to someone else', 'EQUIFAX, INC.', 'PA', '19139', 'None', 'Web', datetime.date(2023, 2, 15), 'Closed with explanation', 'Yes', 6575376),
#  (datetime.date(2023, 3, 8), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'EQUIFAX, INC.', 'FL', '32824', 'None', 'Web', datetime.date(2023, 3, 8), 'In progress', 'Yes', 6658913),
#  (datetime.date(2022, 12, 21), 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'FL', '32127', 'Consent provided', 'Web', datetime.date(2022, 12, 21), 'Closed with non-monetary relief', 'Yes', 6341955),
#  (datetime.date(2023, 2, 14), 'Debt collection', 'Other debt', 'False statements or representation', 'Indicated you were committing crime by not paying debt', 'Security Credit Services, LLC', 'TX', '76040', 'None', 'Web', datetime.date(2023, 2, 14), 'Closed with explanation', 'Yes', 6570583),
#  ...]

# %%
# Reflect Database into ORM class
Base = automap_base()
Base.prepare(autoload_with=engine)
Complaints = Base.classes.complaints

# %%
session = Session(engine)

# %%
sel1 = [Complaints]
data1 = session.query(*sel1).all()
data1
# Out:
# [<sqlalchemy.ext.automap.complaints at 0x2177814b9c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2177814b808>,
#  <sqlalchemy.ext.automap.complaints at 0x2177814b6c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2177814b588>,
#  <sqlalchemy.ext.automap.complaints at 0x2177814bb48>,
#  <sqlalchemy.ext.automap.complaints at 0x2177814b448>,
#  <sqlalchemy.ext.automap.complaints at 0x2177814b308>,
#  <sqlalchemy.ext.automap.complaints at 0x2177814b208>,
#  <sqlalchemy.ext.automap.complaints at 0x2177814b0c8>,
#  <sqlalchemy.ext.automap.complaints at 0x21778139ec8>,
#  <sqlalchemy.ext.automap.complaints at 0x21778139d88>,
#  <sqlalchemy.ext.automap.complaints at 0x21778139c88>,
#  <sqlalchemy.ext.automap.complaints at 0x21778139ac8>,
#  <sqlalchemy.ext.automap.complaints at 0x217781399c8>,
#  <sqlalchemy.ext.automap.complaints at 0x21778139888>,
#  <sqlalchemy.ext.automap.complaints at 0x21778139748>,
#  <sqlalchemy.ext.automap.complaints at 0x217781395c8>,
#  <sqlalchemy.ext.automap.complaints at 0x21778139488>,
#  <sqlalchemy.ext.automap.complaints at 0x217781392c8>,
#  <sqlalchemy.ext.automap.complaints at 0x217781391c8>,
#  <sqlalchemy.ext.automap.complaints at 0x21778144c08>,
#  <sqlalchemy.ext.automap.complaints at 0x21778144b48>,
#  <sqlalchemy.ext.automap.complaints at 0x21778144a08>,
#  <sqlalchemy.ext.automap.complaints at 0x217781447c8>,
#  <sqlalchemy.ext.automap.complaints at 0x21778144808>,
#  <sqlalchemy.ext.automap.complaints at 0x217781446c8>,
#  <sqlalchemy.ext.automap.complaints at 0x21778144e08>,
#  <sqlalchemy.ext.automap.complaints at 0x21778144548>,
#  <sqlalchemy.ext.automap.complaints at 0x217781441c8>,
#  <sqlalchemy.ext.automap.complaints at 0x21778144188>,
#  <sqlalchemy.ext.automap.complaints at 0x21777594e48>,
#  <sqlalchemy.ext.automap.complaints at 0x21778153108>,
#  <sqlalchemy.ext.automap.complaints at 0x21778153a48>,
#  <sqlalchemy.ext.automap.complaints at 0x21779a9b5c8>,
#  <sqlalchemy.ext.automap.complaints at 0x217789051c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2175540f108>,
#  <sqlalchemy.ext.automap.complaints at 0x2177867df48>,
#  <sqlalchemy.ext.automap.complaints at 0x217373acd88>,
#  <sqlalchemy.ext.automap.complaints at 0x217aca26588>,
#  <sqlalchemy.ext.automap.complaints at 0x217aca26688>,
#  <sqlalchemy.ext.automap.complaints at 0x217aca26788>,
#  <sqlalchemy.ext.automap.complaints at 0x217aca26888>,
#  <sqlalchemy.ext.automap.complaints at 0x217aca26988>,
#  <sqlalchemy.ext.automap.complaints at 0x217aca26a88>,
#  <sqlalchemy.ext.automap.complaints at 0x217aca26b88>,
#  <sqlalchemy.ext.automap.complaints at 0x217aca26c88>,
#  <sqlalchemy.ext.automap.complaints at 0x217aca26d88>,
#  <sqlalchemy.ext.automap.complaints at 0x217aca26e88>,
#  <sqlalchemy.ext.automap.complaints at 0x217aca26f88>,
#  <sqlalchemy.ext.automap.complaints at 0x2170bf540c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2170bf541c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2170bf542c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2170bf543c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2170bf544c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2170bf545c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2170bf546c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2170bf547c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2170bf548c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2170bf549c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2170bf54ac8>,
#  <sqlalchemy.ext.automap.complaints at 0x2170bf54bc8>,
#  <sqlalchemy.ext.automap.complaints at 0x2170bf54cc8>,
#  <sqlalchemy.ext.automap.complaints at 0x2170bf54dc8>,
#  <sqlalchemy.ext.automap.complaints at 0x2170bf54ec8>,
#  <sqlalchemy.ext.automap.complaints at 0x2170bf54fc8>,
#  <sqlalchemy.ext.automap.complaints at 0x2170f254108>,
#  <sqlalchemy.ext.automap.complaints at 0x2170f254208>,
#  <sqlalchemy.ext.automap.complaints at 0x2170f254308>,
#  <sqlalchemy.ext.automap.complaints at 0x2170f254408>,
#  <sqlalchemy.ext.automap.complaints at 0x2170f254508>,
#  <sqlalchemy.ext.automap.complaints at 0x2170f254608>,
#  <sqlalchemy.ext.automap.complaints at 0x2170f254708>,
#  <sqlalchemy.ext.automap.complaints at 0x2170f254808>,
#  <sqlalchemy.ext.automap.complaints at 0x2170f254908>,
#  <sqlalchemy.ext.automap.complaints at 0x2170f254a08>,
#  <sqlalchemy.ext.automap.complaints at 0x2170f254b08>,
#  <sqlalchemy.ext.automap.complaints at 0x2170f254c08>,
#  <sqlalchemy.ext.automap.complaints at 0x2170f254d08>,
#  <sqlalchemy.ext.automap.complaints at 0x2170f254e08>,
#  <sqlalchemy.ext.automap.complaints at 0x2170f254f08>,
#  <sqlalchemy.ext.automap.complaints at 0x21710469048>,
#  <sqlalchemy.ext.automap.complaints at 0x21710469148>,
#  <sqlalchemy.ext.automap.complaints at 0x21710469248>,
#  <sqlalchemy.ext.automap.complaints at 0x21710469348>,
#  <sqlalchemy.ext.automap.complaints at 0x21710469448>,
#  <sqlalchemy.ext.automap.complaints at 0x21710469548>,
#  <sqlalchemy.ext.automap.complaints at 0x21710469648>,
#  <sqlalchemy.ext.automap.complaints at 0x21710469748>,
#  <sqlalchemy.ext.automap.complaints at 0x21710469848>,
#  <sqlalchemy.ext.automap.complaints at 0x21710469948>,
#  <sqlalchemy.ext.automap.complaints at 0x21710469a48>,
#  <sqlalchemy.ext.automap.complaints at 0x21710469b48>,
#  <sqlalchemy.ext.automap.complaints at 0x21710469c48>,
#  <sqlalchemy.ext.automap.complaints at 0x21710469d48>,
#  <sqlalchemy.ext.automap.complaints at 0x21710469e48>,
#  <sqlalchemy.ext.automap.complaints at 0x21710469f48>,
#  <sqlalchemy.ext.automap.complaints at 0x217117e4088>,
#  <sqlalchemy.ext.automap.complaints at 0x217117e4188>,
#  <sqlalchemy.ext.automap.complaints at 0x217117e4288>,
#  <sqlalchemy.ext.automap.complaints at 0x217117e4388>,
#  <sqlalchemy.ext.automap.complaints at 0x217117e4488>,
#  <sqlalchemy.ext.automap.complaints at 0x217117e4588>,
#  <sqlalchemy.ext.automap.complaints at 0x217117e4688>,
#  <sqlalchemy.ext.automap.complaints at 0x217117e4788>,
#  <sqlalchemy.ext.automap.complaints at 0x217117e4888>,
#  <sqlalchemy.ext.automap.complaints at 0x217117e4988>,
#  <sqlalchemy.ext.automap.complaints at 0x217117e4a88>,
#  <sqlalchemy.ext.automap.complaints at 0x217117e4b88>,
#  <sqlalchemy.ext.automap.complaints at 0x217117e4c88>,
#  <sqlalchemy.ext.automap.complaints at 0x217117e4d88>,
#  <sqlalchemy.ext.automap.complaints at 0x217117e4e88>,
#  <sqlalchemy.ext.automap.complaints at 0x217117e4f88>,
#  <sqlalchemy.ext.automap.complaints at 0x21711b070c8>,
#  <sqlalchemy.ext.automap.complaints at 0x21711b071c8>,
#  <sqlalchemy.ext.automap.complaints at 0x21711b072c8>,
#  <sqlalchemy.ext.automap.complaints at 0x21711b073c8>,
#  <sqlalchemy.ext.automap.complaints at 0x21711b074c8>,
#  <sqlalchemy.ext.automap.complaints at 0x21711b075c8>,
#  <sqlalchemy.ext.automap.complaints at 0x21711b076c8>,
#  <sqlalchemy.ext.automap.complaints at 0x21711b077c8>,
#  <sqlalchemy.ext.automap.complaints at 0x21711b078c8>,
#  <sqlalchemy.ext.automap.complaints at 0x21711b079c8>,
#  <sqlalchemy.ext.automap.complaints at 0x21711b07ac8>,
#  <sqlalchemy.ext.automap.complaints at 0x21711b07bc8>,
#  <sqlalchemy.ext.automap.complaints at 0x21711b07cc8>,
#  <sqlalchemy.ext.automap.complaints at 0x21711b07dc8>,
#  <sqlalchemy.ext.automap.complaints at 0x21711b07ec8>,
#  <sqlalchemy.ext.automap.complaints at 0x21711b07fc8>,
#  <sqlalchemy.ext.automap.complaints at 0x21712314108>,
#  <sqlalchemy.ext.automap.complaints at 0x21712314208>,
#  <sqlalchemy.ext.automap.complaints at 0x21712314308>,
#  <sqlalchemy.ext.automap.complaints at 0x21712314408>,
#  <sqlalchemy.ext.automap.complaints at 0x21712314508>,
#  <sqlalchemy.ext.automap.complaints at 0x21712314608>,
#  <sqlalchemy.ext.automap.complaints at 0x21712314708>,
#  <sqlalchemy.ext.automap.complaints at 0x21712314808>,
#  <sqlalchemy.ext.automap.complaints at 0x21712314908>,
#  <sqlalchemy.ext.automap.complaints at 0x21712314a08>,
#  <sqlalchemy.ext.automap.complaints at 0x21712314b08>,
#  <sqlalchemy.ext.automap.complaints at 0x21712314c08>,
#  <sqlalchemy.ext.automap.complaints at 0x21712314d08>,
#  <sqlalchemy.ext.automap.complaints at 0x21712314e08>,
#  <sqlalchemy.ext.automap.complaints at 0x21712314f08>,
#  <sqlalchemy.ext.automap.complaints at 0x21716e5c048>,
#  <sqlalchemy.ext.automap.complaints at 0x21716e5c148>,
#  <sqlalchemy.ext.automap.complaints at 0x21716e5c248>,
#  <sqlalchemy.ext.automap.complaints at 0x21716e5c348>,
#  <sqlalchemy.ext.automap.complaints at 0x21716e5c448>,
#  <sqlalchemy.ext.automap.complaints at 0x21716e5c548>,
#  <sqlalchemy.ext.automap.complaints at 0x21716e5c648>,
#  <sqlalchemy.ext.automap.complaints at 0x21716e5c748>,
#  <sqlalchemy.ext.automap.complaints at 0x21716e5c848>,
#  <sqlalchemy.ext.automap.complaints at 0x21716e5c948>,
#  <sqlalchemy.ext.automap.complaints at 0x21716e5ca48>,
#  <sqlalchemy.ext.automap.complaints at 0x21716e5cb48>,
#  <sqlalchemy.ext.automap.complaints at 0x21716e5cc48>,
#  <sqlalchemy.ext.automap.complaints at 0x21716e5cd48>,
#  <sqlalchemy.ext.automap.complaints at 0x21716e5ce48>,
#  <sqlalchemy.ext.automap.complaints at 0x21716e5cf48>,
#  <sqlalchemy.ext.automap.complaints at 0x21717654088>,
#  <sqlalchemy.ext.automap.complaints at 0x21717654188>,
#  <sqlalchemy.ext.automap.complaints at 0x21717654288>,
#  <sqlalchemy.ext.automap.complaints at 0x21717654388>,
#  <sqlalchemy.ext.automap.complaints at 0x21717654488>,
#  <sqlalchemy.ext.automap.complaints at 0x21717654588>,
#  <sqlalchemy.ext.automap.complaints at 0x21717654688>,
#  <sqlalchemy.ext.automap.complaints at 0x21717654788>,
#  <sqlalchemy.ext.automap.complaints at 0x21717654888>,
#  <sqlalchemy.ext.automap.complaints at 0x21717654988>,
#  <sqlalchemy.ext.automap.complaints at 0x21717654a88>,
#  <sqlalchemy.ext.automap.complaints at 0x21717654b88>,
#  <sqlalchemy.ext.automap.complaints at 0x21717654c88>,
#  <sqlalchemy.ext.automap.complaints at 0x21717654d88>,
#  <sqlalchemy.ext.automap.complaints at 0x21717654e88>,
#  <sqlalchemy.ext.automap.complaints at 0x21717654f88>,
#  <sqlalchemy.ext.automap.complaints at 0x21718ad70c8>,
#  <sqlalchemy.ext.automap.complaints at 0x21718ad71c8>,
#  <sqlalchemy.ext.automap.complaints at 0x21718ad72c8>,
#  <sqlalchemy.ext.automap.complaints at 0x21718ad73c8>,
#  <sqlalchemy.ext.automap.complaints at 0x21718ad74c8>,
#  <sqlalchemy.ext.automap.complaints at 0x21718ad75c8>,
#  <sqlalchemy.ext.automap.complaints at 0x21718ad76c8>,
#  <sqlalchemy.ext.automap.complaints at 0x21718ad77c8>,
#  <sqlalchemy.ext.automap.complaints at 0x21718ad78c8>,
#  <sqlalchemy.ext.automap.complaints at 0x21718ad79c8>,
#  <sqlalchemy.ext.automap.complaints at 0x21718ad7ac8>,
#  <sqlalchemy.ext.automap.complaints at 0x21718ad7bc8>,
#  <sqlalchemy.ext.automap.complaints at 0x21718ad7cc8>,
#  <sqlalchemy.ext.automap.complaints at 0x21718ad7dc8>,
#  <sqlalchemy.ext.automap.complaints at 0x21718ad7ec8>,
#  <sqlalchemy.ext.automap.complaints at 0x21718ad7fc8>,
#  <sqlalchemy.ext.automap.complaints at 0x2171936c108>,
#  <sqlalchemy.ext.automap.complaints at 0x2171936c208>,
#  <sqlalchemy.ext.automap.complaints at 0x2171936c308>,
#  <sqlalchemy.ext.automap.complaints at 0x2171936c408>,
#  <sqlalchemy.ext.automap.complaints at 0x2171936c508>,
#  <sqlalchemy.ext.automap.complaints at 0x2171936c608>,
#  <sqlalchemy.ext.automap.complaints at 0x2171936c708>,
#  <sqlalchemy.ext.automap.complaints at 0x2171936c808>,
#  <sqlalchemy.ext.automap.complaints at 0x2171936c908>,
#  <sqlalchemy.ext.automap.complaints at 0x2171936ca08>,
#  <sqlalchemy.ext.automap.complaints at 0x2171936cb08>,
#  <sqlalchemy.ext.automap.complaints at 0x2171936cc08>,
#  <sqlalchemy.ext.automap.complaints at 0x2171936cd08>,
#  <sqlalchemy.ext.automap.complaints at 0x2171936ce08>,
#  <sqlalchemy.ext.automap.complaints at 0x2171936cf08>,
#  <sqlalchemy.ext.automap.complaints at 0x2171ad21048>,
#  <sqlalchemy.ext.automap.complaints at 0x2171ad21148>,
#  <sqlalchemy.ext.automap.complaints at 0x2171ad21248>,
#  <sqlalchemy.ext.automap.complaints at 0x2171ad21348>,
#  <sqlalchemy.ext.automap.complaints at 0x2171ad21448>,
#  <sqlalchemy.ext.automap.complaints at 0x2171ad21548>,
#  <sqlalchemy.ext.automap.complaints at 0x2171ad21648>,
#  <sqlalchemy.ext.automap.complaints at 0x2171ad21748>,
#  <sqlalchemy.ext.automap.complaints at 0x2171ad21848>,
#  <sqlalchemy.ext.automap.complaints at 0x2171ad21948>,
#  <sqlalchemy.ext.automap.complaints at 0x2171ad21a48>,
#  <sqlalchemy.ext.automap.complaints at 0x2171ad21b48>,
#  <sqlalchemy.ext.automap.complaints at 0x2171ad21c48>,
#  <sqlalchemy.ext.automap.complaints at 0x2171ad21d48>,
#  <sqlalchemy.ext.automap.complaints at 0x2171ad21e48>,
#  <sqlalchemy.ext.automap.complaints at 0x2171ad21f48>,
#  <sqlalchemy.ext.automap.complaints at 0x2171b9f9088>,
#  <sqlalchemy.ext.automap.complaints at 0x2171b9f9188>,
#  <sqlalchemy.ext.automap.complaints at 0x2171b9f9288>,
#  <sqlalchemy.ext.automap.complaints at 0x2171b9f9388>,
#  <sqlalchemy.ext.automap.complaints at 0x2171b9f9488>,
#  <sqlalchemy.ext.automap.complaints at 0x2171b9f9588>,
#  <sqlalchemy.ext.automap.complaints at 0x2171b9f9688>,
#  <sqlalchemy.ext.automap.complaints at 0x2171b9f9788>,
#  <sqlalchemy.ext.automap.complaints at 0x2171b9f9888>,
#  <sqlalchemy.ext.automap.complaints at 0x2171b9f9988>,
#  <sqlalchemy.ext.automap.complaints at 0x2171b9f9a88>,
#  <sqlalchemy.ext.automap.complaints at 0x2171b9f9b88>,
#  <sqlalchemy.ext.automap.complaints at 0x2171b9f9c88>,
#  <sqlalchemy.ext.automap.complaints at 0x2171b9f9d88>,
#  <sqlalchemy.ext.automap.complaints at 0x2171b9f9e88>,
#  <sqlalchemy.ext.automap.complaints at 0x2171b9f9f88>,
#  <sqlalchemy.ext.automap.complaints at 0x2171c55a0c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2171c55a1c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2171c55a2c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2171c55a3c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2171c55a4c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2171c55a5c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2171c55a6c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2171c55a7c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2171c55a8c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2171c55a9c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2171c55aac8>,
#  <sqlalchemy.ext.automap.complaints at 0x2171c55abc8>,
#  <sqlalchemy.ext.automap.complaints at 0x2171c55acc8>,
#  <sqlalchemy.ext.automap.complaints at 0x2171c55adc8>,
#  <sqlalchemy.ext.automap.complaints at 0x2171c55aec8>,
#  <sqlalchemy.ext.automap.complaints at 0x2171c55afc8>,
#  <sqlalchemy.ext.automap.complaints at 0x2171d1db108>,
#  <sqlalchemy.ext.automap.complaints at 0x2171d1db208>,
#  <sqlalchemy.ext.automap.complaints at 0x2171d1db308>,
#  <sqlalchemy.ext.automap.complaints at 0x2171d1db408>,
#  <sqlalchemy.ext.automap.complaints at 0x2171d1db508>,
#  <sqlalchemy.ext.automap.complaints at 0x2171d1db608>,
#  <sqlalchemy.ext.automap.complaints at 0x2171d1db708>,
#  <sqlalchemy.ext.automap.complaints at 0x2171d1db808>,
#  <sqlalchemy.ext.automap.complaints at 0x2171d1db908>,
#  <sqlalchemy.ext.automap.complaints at 0x2171d1dba08>,
#  <sqlalchemy.ext.automap.complaints at 0x2171d1dbb08>,
#  <sqlalchemy.ext.automap.complaints at 0x2171d1dbc08>,
#  <sqlalchemy.ext.automap.complaints at 0x2171d1dbd08>,
#  <sqlalchemy.ext.automap.complaints at 0x2171d1dbe08>,
#  <sqlalchemy.ext.automap.complaints at 0x2171d1dbf08>,
#  <sqlalchemy.ext.automap.complaints at 0x2171e679048>,
#  <sqlalchemy.ext.automap.complaints at 0x2171e679148>,
#  <sqlalchemy.ext.automap.complaints at 0x2171e679248>,
#  <sqlalchemy.ext.automap.complaints at 0x2171e679348>,
#  <sqlalchemy.ext.automap.complaints at 0x2171e679448>,
#  <sqlalchemy.ext.automap.complaints at 0x2171e679548>,
#  <sqlalchemy.ext.automap.complaints at 0x2171e679648>,
#  <sqlalchemy.ext.automap.complaints at 0x2171e679748>,
#  <sqlalchemy.ext.automap.complaints at 0x2171e679848>,
#  <sqlalchemy.ext.automap.complaints at 0x2171e679948>,
#  <sqlalchemy.ext.automap.complaints at 0x2171e679a48>,
#  <sqlalchemy.ext.automap.complaints at 0x2171e679b48>,
#  <sqlalchemy.ext.automap.complaints at 0x2171e679c48>,
#  <sqlalchemy.ext.automap.complaints at 0x2171e679d48>,
#  <sqlalchemy.ext.automap.complaints at 0x2171e679e48>,
#  <sqlalchemy.ext.automap.complaints at 0x2171e679f48>,
#  <sqlalchemy.ext.automap.complaints at 0x2171ec0e088>,
#  <sqlalchemy.ext.automap.complaints at 0x2171ec0e188>,
#  <sqlalchemy.ext.automap.complaints at 0x2171ec0e288>,
#  <sqlalchemy.ext.automap.complaints at 0x2171ec0e388>,
#  <sqlalchemy.ext.automap.complaints at 0x2171ec0e488>,
#  <sqlalchemy.ext.automap.complaints at 0x2171ec0e588>,
#  <sqlalchemy.ext.automap.complaints at 0x2171ec0e688>,
#  <sqlalchemy.ext.automap.complaints at 0x2171ec0e788>,
#  <sqlalchemy.ext.automap.complaints at 0x2171ec0e888>,
#  <sqlalchemy.ext.automap.complaints at 0x2171ec0e988>,
#  <sqlalchemy.ext.automap.complaints at 0x2171ec0ea88>,
#  <sqlalchemy.ext.automap.complaints at 0x2171ec0eb88>,
#  <sqlalchemy.ext.automap.complaints at 0x2171ec0ec88>,
#  <sqlalchemy.ext.automap.complaints at 0x2171ec0ed88>,
#  <sqlalchemy.ext.automap.complaints at 0x2171ec0ee88>,
#  <sqlalchemy.ext.automap.complaints at 0x2171ec0ef88>,
#  <sqlalchemy.ext.automap.complaints at 0x2171f6e30c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2171f6e31c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2171f6e32c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2171f6e33c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2171f6e34c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2171f6e35c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2171f6e36c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2171f6e37c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2171f6e38c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2171f6e39c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2171f6e3ac8>,
#  <sqlalchemy.ext.automap.complaints at 0x2171f6e3bc8>,
#  <sqlalchemy.ext.automap.complaints at 0x2171f6e3cc8>,
#  <sqlalchemy.ext.automap.complaints at 0x2171f6e3dc8>,
#  <sqlalchemy.ext.automap.complaints at 0x2171f6e3ec8>,
#  <sqlalchemy.ext.automap.complaints at 0x2171f6e3fc8>,
#  <sqlalchemy.ext.automap.complaints at 0x21720070108>,
#  <sqlalchemy.ext.automap.complaints at 0x21720070208>,
#  <sqlalchemy.ext.automap.complaints at 0x21720070308>,
#  <sqlalchemy.ext.automap.complaints at 0x21720070408>,
#  <sqlalchemy.ext.automap.complaints at 0x21720070508>,
#  <sqlalchemy.ext.automap.complaints at 0x21720070608>,
#  <sqlalchemy.ext.automap.complaints at 0x21720070708>,
#  <sqlalchemy.ext.automap.complaints at 0x21720070808>,
#  <sqlalchemy.ext.automap.complaints at 0x21720070908>,
#  <sqlalchemy.ext.automap.complaints at 0x21720070a08>,
#  <sqlalchemy.ext.automap.complaints at 0x21720070b08>,
#  <sqlalchemy.ext.automap.complaints at 0x21720070c08>,
#  <sqlalchemy.ext.automap.complaints at 0x21720070d08>,
#  <sqlalchemy.ext.automap.complaints at 0x21720070e08>,
#  <sqlalchemy.ext.automap.complaints at 0x21720070f08>,
#  <sqlalchemy.ext.automap.complaints at 0x21720494048>,
#  <sqlalchemy.ext.automap.complaints at 0x21720494148>,
#  <sqlalchemy.ext.automap.complaints at 0x21720494248>,
#  <sqlalchemy.ext.automap.complaints at 0x21720494348>,
#  <sqlalchemy.ext.automap.complaints at 0x21720494448>,
#  <sqlalchemy.ext.automap.complaints at 0x21720494548>,
#  <sqlalchemy.ext.automap.complaints at 0x21720494648>,
#  <sqlalchemy.ext.automap.complaints at 0x21720494748>,
#  <sqlalchemy.ext.automap.complaints at 0x21720494848>,
#  <sqlalchemy.ext.automap.complaints at 0x21720494948>,
#  <sqlalchemy.ext.automap.complaints at 0x21720494a48>,
#  <sqlalchemy.ext.automap.complaints at 0x21720494b48>,
#  <sqlalchemy.ext.automap.complaints at 0x21720494c48>,
#  <sqlalchemy.ext.automap.complaints at 0x21720494d48>,
#  <sqlalchemy.ext.automap.complaints at 0x21720494e48>,
#  <sqlalchemy.ext.automap.complaints at 0x21720494f48>,
#  <sqlalchemy.ext.automap.complaints at 0x2172235c088>,
#  <sqlalchemy.ext.automap.complaints at 0x2172235c188>,
#  <sqlalchemy.ext.automap.complaints at 0x2172235c288>,
#  <sqlalchemy.ext.automap.complaints at 0x2172235c388>,
#  <sqlalchemy.ext.automap.complaints at 0x2172235c488>,
#  <sqlalchemy.ext.automap.complaints at 0x2172235c588>,
#  <sqlalchemy.ext.automap.complaints at 0x2172235c688>,
#  <sqlalchemy.ext.automap.complaints at 0x2172235c788>,
#  <sqlalchemy.ext.automap.complaints at 0x2172235c888>,
#  <sqlalchemy.ext.automap.complaints at 0x2172235c988>,
#  <sqlalchemy.ext.automap.complaints at 0x2172235ca88>,
#  <sqlalchemy.ext.automap.complaints at 0x2172235cb88>,
#  <sqlalchemy.ext.automap.complaints at 0x2172235cc88>,
#  <sqlalchemy.ext.automap.complaints at 0x2172235cd88>,
#  <sqlalchemy.ext.automap.complaints at 0x2172235ce88>,
#  <sqlalchemy.ext.automap.complaints at 0x2172235cf88>,
#  <sqlalchemy.ext.automap.complaints at 0x217250730c8>,
#  <sqlalchemy.ext.automap.complaints at 0x217250731c8>,
#  <sqlalchemy.ext.automap.complaints at 0x217250732c8>,
#  <sqlalchemy.ext.automap.complaints at 0x217250733c8>,
#  <sqlalchemy.ext.automap.complaints at 0x217250734c8>,
#  <sqlalchemy.ext.automap.complaints at 0x217250735c8>,
#  <sqlalchemy.ext.automap.complaints at 0x217250736c8>,
#  <sqlalchemy.ext.automap.complaints at 0x217250737c8>,
#  <sqlalchemy.ext.automap.complaints at 0x217250738c8>,
#  <sqlalchemy.ext.automap.complaints at 0x217250739c8>,
#  <sqlalchemy.ext.automap.complaints at 0x21725073ac8>,
#  <sqlalchemy.ext.automap.complaints at 0x21725073bc8>,
#  <sqlalchemy.ext.automap.complaints at 0x21725073cc8>,
#  <sqlalchemy.ext.automap.complaints at 0x21725073dc8>,
#  <sqlalchemy.ext.automap.complaints at 0x21725073ec8>,
#  <sqlalchemy.ext.automap.complaints at 0x21725073fc8>,
#  <sqlalchemy.ext.automap.complaints at 0x217262f8108>,
#  <sqlalchemy.ext.automap.complaints at 0x217262f8208>,
#  <sqlalchemy.ext.automap.complaints at 0x217262f8308>,
#  <sqlalchemy.ext.automap.complaints at 0x217262f8408>,
#  <sqlalchemy.ext.automap.complaints at 0x217262f8508>,
#  <sqlalchemy.ext.automap.complaints at 0x217262f8608>,
#  <sqlalchemy.ext.automap.complaints at 0x217262f8708>,
#  <sqlalchemy.ext.automap.complaints at 0x217262f8808>,
#  <sqlalchemy.ext.automap.complaints at 0x217262f8908>,
#  <sqlalchemy.ext.automap.complaints at 0x217262f8a08>,
#  <sqlalchemy.ext.automap.complaints at 0x217262f8b08>,
#  <sqlalchemy.ext.automap.complaints at 0x217262f8c08>,
#  <sqlalchemy.ext.automap.complaints at 0x217262f8d08>,
#  <sqlalchemy.ext.automap.complaints at 0x217262f8e08>,
#  <sqlalchemy.ext.automap.complaints at 0x217262f8f08>,
#  <sqlalchemy.ext.automap.complaints at 0x21729a95048>,
#  <sqlalchemy.ext.automap.complaints at 0x21729a95148>,
#  <sqlalchemy.ext.automap.complaints at 0x21729a95248>,
#  <sqlalchemy.ext.automap.complaints at 0x21729a95348>,
#  <sqlalchemy.ext.automap.complaints at 0x21729a95448>,
#  <sqlalchemy.ext.automap.complaints at 0x21729a95548>,
#  <sqlalchemy.ext.automap.complaints at 0x21729a95648>,
#  <sqlalchemy.ext.automap.complaints at 0x21729a95748>,
#  <sqlalchemy.ext.automap.complaints at 0x21729a95848>,
#  <sqlalchemy.ext.automap.complaints at 0x21729a95948>,
#  <sqlalchemy.ext.automap.complaints at 0x21729a95a48>,
#  <sqlalchemy.ext.automap.complaints at 0x21729a95b48>,
#  <sqlalchemy.ext.automap.complaints at 0x21729a95c48>,
#  <sqlalchemy.ext.automap.complaints at 0x21729a95d48>,
#  <sqlalchemy.ext.automap.complaints at 0x21729a95e48>,
#  <sqlalchemy.ext.automap.complaints at 0x21729a95f48>,
#  <sqlalchemy.ext.automap.complaints at 0x2172a8f9088>,
#  <sqlalchemy.ext.automap.complaints at 0x2172a8f9188>,
#  <sqlalchemy.ext.automap.complaints at 0x2172a8f9288>,
#  <sqlalchemy.ext.automap.complaints at 0x2172a8f9388>,
#  <sqlalchemy.ext.automap.complaints at 0x2172a8f9488>,
#  <sqlalchemy.ext.automap.complaints at 0x2172a8f9588>,
#  <sqlalchemy.ext.automap.complaints at 0x2172a8f9688>,
#  <sqlalchemy.ext.automap.complaints at 0x2172a8f9788>,
#  <sqlalchemy.ext.automap.complaints at 0x2172a8f9888>,
#  <sqlalchemy.ext.automap.complaints at 0x2172a8f9988>,
#  <sqlalchemy.ext.automap.complaints at 0x2172a8f9a88>,
#  <sqlalchemy.ext.automap.complaints at 0x2172a8f9b88>,
#  <sqlalchemy.ext.automap.complaints at 0x2172a8f9c88>,
#  <sqlalchemy.ext.automap.complaints at 0x2172a8f9d88>,
#  <sqlalchemy.ext.automap.complaints at 0x2172a8f9e88>,
#  <sqlalchemy.ext.automap.complaints at 0x2172a8f9f88>,
#  <sqlalchemy.ext.automap.complaints at 0x2172cb4f0c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2172cb4f1c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2172cb4f2c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2172cb4f3c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2172cb4f4c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2172cb4f5c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2172cb4f6c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2172cb4f7c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2172cb4f8c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2172cb4f9c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2172cb4fac8>,
#  <sqlalchemy.ext.automap.complaints at 0x2172cb4fbc8>,
#  <sqlalchemy.ext.automap.complaints at 0x2172cb4fcc8>,
#  <sqlalchemy.ext.automap.complaints at 0x2172cb4fdc8>,
#  <sqlalchemy.ext.automap.complaints at 0x2172cb4fec8>,
#  <sqlalchemy.ext.automap.complaints at 0x2172cb4ffc8>,
#  <sqlalchemy.ext.automap.complaints at 0x217301dc108>,
#  <sqlalchemy.ext.automap.complaints at 0x217301dc208>,
#  <sqlalchemy.ext.automap.complaints at 0x217301dc308>,
#  <sqlalchemy.ext.automap.complaints at 0x217301dc408>,
#  <sqlalchemy.ext.automap.complaints at 0x217301dc508>,
#  <sqlalchemy.ext.automap.complaints at 0x217301dc608>,
#  <sqlalchemy.ext.automap.complaints at 0x217301dc708>,
#  <sqlalchemy.ext.automap.complaints at 0x217301dc808>,
#  <sqlalchemy.ext.automap.complaints at 0x217301dc908>,
#  <sqlalchemy.ext.automap.complaints at 0x217301dca08>,
#  <sqlalchemy.ext.automap.complaints at 0x217301dcb08>,
#  <sqlalchemy.ext.automap.complaints at 0x217301dcc08>,
#  <sqlalchemy.ext.automap.complaints at 0x217301dcd08>,
#  <sqlalchemy.ext.automap.complaints at 0x217301dce08>,
#  <sqlalchemy.ext.automap.complaints at 0x217301dcf08>,
#  <sqlalchemy.ext.automap.complaints at 0x2173112b048>,
#  <sqlalchemy.ext.automap.complaints at 0x2173112b148>,
#  <sqlalchemy.ext.automap.complaints at 0x2173112b248>,
#  <sqlalchemy.ext.automap.complaints at 0x2173112b348>,
#  <sqlalchemy.ext.automap.complaints at 0x2173112b448>,
#  <sqlalchemy.ext.automap.complaints at 0x2173112b548>,
#  <sqlalchemy.ext.automap.complaints at 0x2173112b648>,
#  <sqlalchemy.ext.automap.complaints at 0x2173112b748>,
#  <sqlalchemy.ext.automap.complaints at 0x2173112b848>,
#  <sqlalchemy.ext.automap.complaints at 0x2173112b948>,
#  <sqlalchemy.ext.automap.complaints at 0x2173112ba48>,
#  <sqlalchemy.ext.automap.complaints at 0x2173112bb48>,
#  <sqlalchemy.ext.automap.complaints at 0x2173112bc48>,
#  <sqlalchemy.ext.automap.complaints at 0x2173112bd48>,
#  <sqlalchemy.ext.automap.complaints at 0x2173112be48>,
#  <sqlalchemy.ext.automap.complaints at 0x2173112bf48>,
#  <sqlalchemy.ext.automap.complaints at 0x21732ab1088>,
#  <sqlalchemy.ext.automap.complaints at 0x21732ab1188>,
#  <sqlalchemy.ext.automap.complaints at 0x21732ab1288>,
#  <sqlalchemy.ext.automap.complaints at 0x21732ab1388>,
#  <sqlalchemy.ext.automap.complaints at 0x21732ab1488>,
#  <sqlalchemy.ext.automap.complaints at 0x21732ab1588>,
#  <sqlalchemy.ext.automap.complaints at 0x21732ab1688>,
#  <sqlalchemy.ext.automap.complaints at 0x21732ab1788>,
#  <sqlalchemy.ext.automap.complaints at 0x21732ab1888>,
#  <sqlalchemy.ext.automap.complaints at 0x21732ab1988>,
#  <sqlalchemy.ext.automap.complaints at 0x21732ab1a88>,
#  <sqlalchemy.ext.automap.complaints at 0x21732ab1b88>,
#  <sqlalchemy.ext.automap.complaints at 0x21732ab1c88>,
#  <sqlalchemy.ext.automap.complaints at 0x21732ab1d88>,
#  <sqlalchemy.ext.automap.complaints at 0x21732ab1e88>,
#  <sqlalchemy.ext.automap.complaints at 0x21732ab1f88>,
#  <sqlalchemy.ext.automap.complaints at 0x217358d00c8>,
#  <sqlalchemy.ext.automap.complaints at 0x217358d01c8>,
#  <sqlalchemy.ext.automap.complaints at 0x217358d02c8>,
#  <sqlalchemy.ext.automap.complaints at 0x217358d03c8>,
#  <sqlalchemy.ext.automap.complaints at 0x217358d04c8>,
#  <sqlalchemy.ext.automap.complaints at 0x217358d05c8>,
#  <sqlalchemy.ext.automap.complaints at 0x217358d06c8>,
#  <sqlalchemy.ext.automap.complaints at 0x217358d07c8>,
#  <sqlalchemy.ext.automap.complaints at 0x217358d08c8>,
#  <sqlalchemy.ext.automap.complaints at 0x217358d09c8>,
#  <sqlalchemy.ext.automap.complaints at 0x217358d0ac8>,
#  <sqlalchemy.ext.automap.complaints at 0x217358d0bc8>,
#  <sqlalchemy.ext.automap.complaints at 0x217358d0cc8>,
#  <sqlalchemy.ext.automap.complaints at 0x217358d0dc8>,
#  <sqlalchemy.ext.automap.complaints at 0x217358d0ec8>,
#  <sqlalchemy.ext.automap.complaints at 0x217358d0fc8>,
#  <sqlalchemy.ext.automap.complaints at 0x2173651c108>,
#  <sqlalchemy.ext.automap.complaints at 0x2173651c208>,
#  <sqlalchemy.ext.automap.complaints at 0x2173651c308>,
#  <sqlalchemy.ext.automap.complaints at 0x2173651c408>,
#  <sqlalchemy.ext.automap.complaints at 0x2173651c508>,
#  <sqlalchemy.ext.automap.complaints at 0x2173651c608>,
#  <sqlalchemy.ext.automap.complaints at 0x2173651c708>,
#  <sqlalchemy.ext.automap.complaints at 0x2173651c808>,
#  <sqlalchemy.ext.automap.complaints at 0x2173651c908>,
#  <sqlalchemy.ext.automap.complaints at 0x2173651ca08>,
#  <sqlalchemy.ext.automap.complaints at 0x2173651cb08>,
#  <sqlalchemy.ext.automap.complaints at 0x2173651cc08>,
#  <sqlalchemy.ext.automap.complaints at 0x2173651cd08>,
#  <sqlalchemy.ext.automap.complaints at 0x2173651ce08>,
#  <sqlalchemy.ext.automap.complaints at 0x2173651cf08>,
#  <sqlalchemy.ext.automap.complaints at 0x2175b4f6048>,
#  <sqlalchemy.ext.automap.complaints at 0x2175b4f6148>,
#  <sqlalchemy.ext.automap.complaints at 0x2175b4f6248>,
#  <sqlalchemy.ext.automap.complaints at 0x2175b4f6348>,
#  <sqlalchemy.ext.automap.complaints at 0x2175b4f6448>,
#  <sqlalchemy.ext.automap.complaints at 0x2175b4f6548>,
#  <sqlalchemy.ext.automap.complaints at 0x2175b4f6648>,
#  <sqlalchemy.ext.automap.complaints at 0x2175b4f6748>,
#  <sqlalchemy.ext.automap.complaints at 0x2175b4f6848>,
#  <sqlalchemy.ext.automap.complaints at 0x2175b4f6948>,
#  <sqlalchemy.ext.automap.complaints at 0x2175b4f6a48>,
#  <sqlalchemy.ext.automap.complaints at 0x2175b4f6b48>,
#  <sqlalchemy.ext.automap.complaints at 0x2175b4f6c48>,
#  <sqlalchemy.ext.automap.complaints at 0x2175b4f6d48>,
#  <sqlalchemy.ext.automap.complaints at 0x2175b4f6e48>,
#  <sqlalchemy.ext.automap.complaints at 0x2175b4f6f48>,
#  <sqlalchemy.ext.automap.complaints at 0x2175b6d9088>,
#  <sqlalchemy.ext.automap.complaints at 0x2175b6d9188>,
#  <sqlalchemy.ext.automap.complaints at 0x2175b6d9288>,
#  <sqlalchemy.ext.automap.complaints at 0x2175b6d9388>,
#  <sqlalchemy.ext.automap.complaints at 0x2175b6d9488>,
#  <sqlalchemy.ext.automap.complaints at 0x2175b6d9588>,
#  <sqlalchemy.ext.automap.complaints at 0x2175b6d9688>,
#  <sqlalchemy.ext.automap.complaints at 0x2175b6d9788>,
#  <sqlalchemy.ext.automap.complaints at 0x2175b6d9888>,
#  <sqlalchemy.ext.automap.complaints at 0x2175b6d9988>,
#  <sqlalchemy.ext.automap.complaints at 0x2175b6d9a88>,
#  <sqlalchemy.ext.automap.complaints at 0x2175b6d9b88>,
#  <sqlalchemy.ext.automap.complaints at 0x2175b6d9c88>,
#  <sqlalchemy.ext.automap.complaints at 0x2175b6d9d88>,
#  <sqlalchemy.ext.automap.complaints at 0x2175b6d9e88>,
#  <sqlalchemy.ext.automap.complaints at 0x2175b6d9f88>,
#  <sqlalchemy.ext.automap.complaints at 0x2175f7bf0c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2175f7bf1c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2175f7bf2c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2175f7bf3c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2175f7bf4c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2175f7bf5c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2175f7bf6c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2175f7bf7c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2175f7bf8c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2175f7bf9c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2175f7bfac8>,
#  <sqlalchemy.ext.automap.complaints at 0x2175f7bfbc8>,
#  <sqlalchemy.ext.automap.complaints at 0x2175f7bfcc8>,
#  <sqlalchemy.ext.automap.complaints at 0x2175f7bfdc8>,
#  <sqlalchemy.ext.automap.complaints at 0x2175f7bfec8>,
#  <sqlalchemy.ext.automap.complaints at 0x2175f7bffc8>,
#  <sqlalchemy.ext.automap.complaints at 0x2175f9a8108>,
#  <sqlalchemy.ext.automap.complaints at 0x2175f9a8208>,
#  <sqlalchemy.ext.automap.complaints at 0x2175f9a8308>,
#  <sqlalchemy.ext.automap.complaints at 0x2175f9a8408>,
#  <sqlalchemy.ext.automap.complaints at 0x2175f9a8508>,
#  <sqlalchemy.ext.automap.complaints at 0x2175f9a8608>,
#  <sqlalchemy.ext.automap.complaints at 0x2175f9a8708>,
#  <sqlalchemy.ext.automap.complaints at 0x2175f9a8808>,
#  <sqlalchemy.ext.automap.complaints at 0x2175f9a8908>,
#  <sqlalchemy.ext.automap.complaints at 0x2175f9a8a08>,
#  <sqlalchemy.ext.automap.complaints at 0x2175f9a8b08>,
#  <sqlalchemy.ext.automap.complaints at 0x2175f9a8c08>,
#  <sqlalchemy.ext.automap.complaints at 0x2175f9a8d08>,
#  <sqlalchemy.ext.automap.complaints at 0x2175f9a8e08>,
#  <sqlalchemy.ext.automap.complaints at 0x2175f9a8f08>,
#  <sqlalchemy.ext.automap.complaints at 0x21777799048>,
#  <sqlalchemy.ext.automap.complaints at 0x21777799148>,
#  <sqlalchemy.ext.automap.complaints at 0x21777799248>,
#  <sqlalchemy.ext.automap.complaints at 0x21777799348>,
#  <sqlalchemy.ext.automap.complaints at 0x21777799448>,
#  <sqlalchemy.ext.automap.complaints at 0x21777799548>,
#  <sqlalchemy.ext.automap.complaints at 0x21777799648>,
#  <sqlalchemy.ext.automap.complaints at 0x21777799748>,
#  <sqlalchemy.ext.automap.complaints at 0x21777799848>,
#  <sqlalchemy.ext.automap.complaints at 0x21777799948>,
#  <sqlalchemy.ext.automap.complaints at 0x21777799a48>,
#  <sqlalchemy.ext.automap.complaints at 0x21777799b48>,
#  <sqlalchemy.ext.automap.complaints at 0x21777799c48>,
#  <sqlalchemy.ext.automap.complaints at 0x21777799d48>,
#  <sqlalchemy.ext.automap.complaints at 0x21777799e48>,
#  <sqlalchemy.ext.automap.complaints at 0x21777799f48>,
#  <sqlalchemy.ext.automap.complaints at 0x21777a07088>,
#  <sqlalchemy.ext.automap.complaints at 0x21777a07188>,
#  <sqlalchemy.ext.automap.complaints at 0x21777a07288>,
#  <sqlalchemy.ext.automap.complaints at 0x21777a07388>,
#  <sqlalchemy.ext.automap.complaints at 0x21777a07488>,
#  <sqlalchemy.ext.automap.complaints at 0x21777a07588>,
#  <sqlalchemy.ext.automap.complaints at 0x21777a07688>,
#  <sqlalchemy.ext.automap.complaints at 0x21777a07788>,
#  <sqlalchemy.ext.automap.complaints at 0x21777a07888>,
#  <sqlalchemy.ext.automap.complaints at 0x21777a07988>,
#  <sqlalchemy.ext.automap.complaints at 0x21777a07a88>,
#  <sqlalchemy.ext.automap.complaints at 0x21777a07b88>,
#  <sqlalchemy.ext.automap.complaints at 0x21777a07c88>,
#  <sqlalchemy.ext.automap.complaints at 0x21777a07d88>,
#  <sqlalchemy.ext.automap.complaints at 0x21777a07e88>,
#  <sqlalchemy.ext.automap.complaints at 0x21777a07f88>,
#  <sqlalchemy.ext.automap.complaints at 0x21777bce0c8>,
#  <sqlalchemy.ext.automap.complaints at 0x21777bce1c8>,
#  <sqlalchemy.ext.automap.complaints at 0x21777bce2c8>,
#  <sqlalchemy.ext.automap.complaints at 0x21777bce3c8>,
#  <sqlalchemy.ext.automap.complaints at 0x21777bce4c8>,
#  <sqlalchemy.ext.automap.complaints at 0x21777bce5c8>,
#  <sqlalchemy.ext.automap.complaints at 0x21777bce6c8>,
#  <sqlalchemy.ext.automap.complaints at 0x21777bce7c8>,
#  <sqlalchemy.ext.automap.complaints at 0x21777bce8c8>,
#  <sqlalchemy.ext.automap.complaints at 0x21777bce9c8>,
#  <sqlalchemy.ext.automap.complaints at 0x21777bceac8>,
#  <sqlalchemy.ext.automap.complaints at 0x21777bcebc8>,
#  <sqlalchemy.ext.automap.complaints at 0x21777bcecc8>,
#  <sqlalchemy.ext.automap.complaints at 0x21777bcedc8>,
#  <sqlalchemy.ext.automap.complaints at 0x21777bceec8>,
#  <sqlalchemy.ext.automap.complaints at 0x21777bcefc8>,
#  <sqlalchemy.ext.automap.complaints at 0x21777cf9108>,
#  <sqlalchemy.ext.automap.complaints at 0x21777cf9208>,
#  <sqlalchemy.ext.automap.complaints at 0x21777cf9308>,
#  <sqlalchemy.ext.automap.complaints at 0x21777cf9408>,
#  <sqlalchemy.ext.automap.complaints at 0x21777cf9508>,
#  <sqlalchemy.ext.automap.complaints at 0x21777cf9608>,
#  <sqlalchemy.ext.automap.complaints at 0x21777cf9708>,
#  <sqlalchemy.ext.automap.complaints at 0x21777cf9808>,
#  <sqlalchemy.ext.automap.complaints at 0x21777cf9908>,
#  <sqlalchemy.ext.automap.complaints at 0x21777cf9a08>,
#  <sqlalchemy.ext.automap.complaints at 0x21777cf9b08>,
#  <sqlalchemy.ext.automap.complaints at 0x21777cf9c08>,
#  <sqlalchemy.ext.automap.complaints at 0x21777cf9d08>,
#  <sqlalchemy.ext.automap.complaints at 0x21777cf9e08>,
#  <sqlalchemy.ext.automap.complaints at 0x21777cf9f08>,
#  <sqlalchemy.ext.automap.complaints at 0x21777f57048>,
#  <sqlalchemy.ext.automap.complaints at 0x21777f57148>,
#  <sqlalchemy.ext.automap.complaints at 0x21777f57248>,
#  <sqlalchemy.ext.automap.complaints at 0x21777f57348>,
#  <sqlalchemy.ext.automap.complaints at 0x21777f57448>,
#  <sqlalchemy.ext.automap.complaints at 0x21777f57548>,
#  <sqlalchemy.ext.automap.complaints at 0x21777f57648>,
#  <sqlalchemy.ext.automap.complaints at 0x21777f57748>,
#  <sqlalchemy.ext.automap.complaints at 0x21777f57848>,
#  <sqlalchemy.ext.automap.complaints at 0x21777f57948>,
#  <sqlalchemy.ext.automap.complaints at 0x21777f57a48>,
#  <sqlalchemy.ext.automap.complaints at 0x21777f57b48>,
#  <sqlalchemy.ext.automap.complaints at 0x21777f57c48>,
#  <sqlalchemy.ext.automap.complaints at 0x21777f57d48>,
#  <sqlalchemy.ext.automap.complaints at 0x21777f57e48>,
#  <sqlalchemy.ext.automap.complaints at 0x21777f57f48>,
#  <sqlalchemy.ext.automap.complaints at 0x21778059088>,
#  <sqlalchemy.ext.automap.complaints at 0x21778059188>,
#  <sqlalchemy.ext.automap.complaints at 0x21778059288>,
#  <sqlalchemy.ext.automap.complaints at 0x21778059388>,
#  <sqlalchemy.ext.automap.complaints at 0x21778059488>,
#  <sqlalchemy.ext.automap.complaints at 0x21778059588>,
#  <sqlalchemy.ext.automap.complaints at 0x21778059688>,
#  <sqlalchemy.ext.automap.complaints at 0x21778059788>,
#  <sqlalchemy.ext.automap.complaints at 0x21778059888>,
#  <sqlalchemy.ext.automap.complaints at 0x21778059988>,
#  <sqlalchemy.ext.automap.complaints at 0x21778059a88>,
#  <sqlalchemy.ext.automap.complaints at 0x21778059b88>,
#  <sqlalchemy.ext.automap.complaints at 0x21778059c88>,
#  <sqlalchemy.ext.automap.complaints at 0x21778059d88>,
#  <sqlalchemy.ext.automap.complaints at 0x21778059e88>,
#  <sqlalchemy.ext.automap.complaints at 0x21778059f88>,
#  <sqlalchemy.ext.automap.complaints at 0x2177830b0c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2177830b1c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2177830b2c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2177830b3c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2177830b4c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2177830b5c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2177830b6c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2177830b7c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2177830b8c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2177830b9c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2177830bac8>,
#  <sqlalchemy.ext.automap.complaints at 0x2177830bbc8>,
#  <sqlalchemy.ext.automap.complaints at 0x2177830bcc8>,
#  <sqlalchemy.ext.automap.complaints at 0x2177830bdc8>,
#  <sqlalchemy.ext.automap.complaints at 0x2177830bec8>,
#  <sqlalchemy.ext.automap.complaints at 0x2177830bfc8>,
#  <sqlalchemy.ext.automap.complaints at 0x21778591108>,
#  <sqlalchemy.ext.automap.complaints at 0x21778591208>,
#  <sqlalchemy.ext.automap.complaints at 0x21778591308>,
#  <sqlalchemy.ext.automap.complaints at 0x21778591408>,
#  <sqlalchemy.ext.automap.complaints at 0x21778591508>,
#  <sqlalchemy.ext.automap.complaints at 0x21778591608>,
#  <sqlalchemy.ext.automap.complaints at 0x21778591708>,
#  <sqlalchemy.ext.automap.complaints at 0x21778591808>,
#  <sqlalchemy.ext.automap.complaints at 0x21778591908>,
#  <sqlalchemy.ext.automap.complaints at 0x21778591a08>,
#  <sqlalchemy.ext.automap.complaints at 0x21778591b08>,
#  <sqlalchemy.ext.automap.complaints at 0x21778591c08>,
#  <sqlalchemy.ext.automap.complaints at 0x21778591d08>,
#  <sqlalchemy.ext.automap.complaints at 0x21778591e08>,
#  <sqlalchemy.ext.automap.complaints at 0x21778591f08>,
#  <sqlalchemy.ext.automap.complaints at 0x217787fe048>,
#  <sqlalchemy.ext.automap.complaints at 0x217787fe148>,
#  <sqlalchemy.ext.automap.complaints at 0x217787fe248>,
#  <sqlalchemy.ext.automap.complaints at 0x217787fe348>,
#  <sqlalchemy.ext.automap.complaints at 0x217787fe448>,
#  <sqlalchemy.ext.automap.complaints at 0x217787fe548>,
#  <sqlalchemy.ext.automap.complaints at 0x217787fe648>,
#  <sqlalchemy.ext.automap.complaints at 0x217787fe748>,
#  <sqlalchemy.ext.automap.complaints at 0x217787fe848>,
#  <sqlalchemy.ext.automap.complaints at 0x217787fe948>,
#  <sqlalchemy.ext.automap.complaints at 0x217787fea48>,
#  <sqlalchemy.ext.automap.complaints at 0x217787feb48>,
#  <sqlalchemy.ext.automap.complaints at 0x217787fec48>,
#  <sqlalchemy.ext.automap.complaints at 0x217787fed48>,
#  <sqlalchemy.ext.automap.complaints at 0x217787fee48>,
#  <sqlalchemy.ext.automap.complaints at 0x217787fef48>,
#  <sqlalchemy.ext.automap.complaints at 0x21778b06088>,
#  <sqlalchemy.ext.automap.complaints at 0x21778b06188>,
#  <sqlalchemy.ext.automap.complaints at 0x21778b06288>,
#  <sqlalchemy.ext.automap.complaints at 0x21778b06388>,
#  <sqlalchemy.ext.automap.complaints at 0x21778b06488>,
#  <sqlalchemy.ext.automap.complaints at 0x21778b06588>,
#  <sqlalchemy.ext.automap.complaints at 0x21778b06688>,
#  <sqlalchemy.ext.automap.complaints at 0x21778b06788>,
#  <sqlalchemy.ext.automap.complaints at 0x21778b06888>,
#  <sqlalchemy.ext.automap.complaints at 0x21778b06988>,
#  <sqlalchemy.ext.automap.complaints at 0x21778b06a88>,
#  <sqlalchemy.ext.automap.complaints at 0x21778b06b88>,
#  <sqlalchemy.ext.automap.complaints at 0x21778b06c88>,
#  <sqlalchemy.ext.automap.complaints at 0x21778b06d88>,
#  <sqlalchemy.ext.automap.complaints at 0x21778b06e88>,
#  <sqlalchemy.ext.automap.complaints at 0x21778b06f88>,
#  <sqlalchemy.ext.automap.complaints at 0x21778cd90c8>,
#  <sqlalchemy.ext.automap.complaints at 0x21778cd91c8>,
#  <sqlalchemy.ext.automap.complaints at 0x21778cd92c8>,
#  <sqlalchemy.ext.automap.complaints at 0x21778cd93c8>,
#  <sqlalchemy.ext.automap.complaints at 0x21778cd94c8>,
#  <sqlalchemy.ext.automap.complaints at 0x21778cd95c8>,
#  <sqlalchemy.ext.automap.complaints at 0x21778cd96c8>,
#  <sqlalchemy.ext.automap.complaints at 0x21778cd97c8>,
#  <sqlalchemy.ext.automap.complaints at 0x21778cd98c8>,
#  <sqlalchemy.ext.automap.complaints at 0x21778cd99c8>,
#  <sqlalchemy.ext.automap.complaints at 0x21778cd9ac8>,
#  <sqlalchemy.ext.automap.complaints at 0x21778cd9bc8>,
#  <sqlalchemy.ext.automap.complaints at 0x21778cd9cc8>,
#  <sqlalchemy.ext.automap.complaints at 0x21778cd9dc8>,
#  <sqlalchemy.ext.automap.complaints at 0x21778cd9ec8>,
#  <sqlalchemy.ext.automap.complaints at 0x21778cd9fc8>,
#  <sqlalchemy.ext.automap.complaints at 0x21778e9e108>,
#  <sqlalchemy.ext.automap.complaints at 0x21778e9e208>,
#  <sqlalchemy.ext.automap.complaints at 0x21778e9e308>,
#  <sqlalchemy.ext.automap.complaints at 0x21778e9e408>,
#  <sqlalchemy.ext.automap.complaints at 0x21778e9e508>,
#  <sqlalchemy.ext.automap.complaints at 0x21778e9e608>,
#  <sqlalchemy.ext.automap.complaints at 0x21778e9e708>,
#  <sqlalchemy.ext.automap.complaints at 0x21778e9e808>,
#  <sqlalchemy.ext.automap.complaints at 0x21778e9e908>,
#  <sqlalchemy.ext.automap.complaints at 0x21778e9ea08>,
#  <sqlalchemy.ext.automap.complaints at 0x21778e9eb08>,
#  <sqlalchemy.ext.automap.complaints at 0x21778e9ec08>,
#  <sqlalchemy.ext.automap.complaints at 0x21778e9ed08>,
#  <sqlalchemy.ext.automap.complaints at 0x21778e9ee08>,
#  <sqlalchemy.ext.automap.complaints at 0x21778e9ef08>,
#  <sqlalchemy.ext.automap.complaints at 0x21779001048>,
#  <sqlalchemy.ext.automap.complaints at 0x21779001148>,
#  <sqlalchemy.ext.automap.complaints at 0x21779001248>,
#  <sqlalchemy.ext.automap.complaints at 0x21779001348>,
#  <sqlalchemy.ext.automap.complaints at 0x21779001448>,
#  <sqlalchemy.ext.automap.complaints at 0x21779001548>,
#  <sqlalchemy.ext.automap.complaints at 0x21779001648>,
#  <sqlalchemy.ext.automap.complaints at 0x21779001748>,
#  <sqlalchemy.ext.automap.complaints at 0x21779001848>,
#  <sqlalchemy.ext.automap.complaints at 0x21779001948>,
#  <sqlalchemy.ext.automap.complaints at 0x21779001a48>,
#  <sqlalchemy.ext.automap.complaints at 0x21779001b48>,
#  <sqlalchemy.ext.automap.complaints at 0x21779001c48>,
#  <sqlalchemy.ext.automap.complaints at 0x21779001d48>,
#  <sqlalchemy.ext.automap.complaints at 0x21779001e48>,
#  <sqlalchemy.ext.automap.complaints at 0x21779001f48>,
#  <sqlalchemy.ext.automap.complaints at 0x2177919b088>,
#  <sqlalchemy.ext.automap.complaints at 0x2177919b188>,
#  <sqlalchemy.ext.automap.complaints at 0x2177919b288>,
#  <sqlalchemy.ext.automap.complaints at 0x2177919b388>,
#  <sqlalchemy.ext.automap.complaints at 0x2177919b488>,
#  <sqlalchemy.ext.automap.complaints at 0x2177919b588>,
#  <sqlalchemy.ext.automap.complaints at 0x2177919b688>,
#  <sqlalchemy.ext.automap.complaints at 0x2177919b788>,
#  <sqlalchemy.ext.automap.complaints at 0x2177919b888>,
#  <sqlalchemy.ext.automap.complaints at 0x2177919b988>,
#  <sqlalchemy.ext.automap.complaints at 0x2177919ba88>,
#  <sqlalchemy.ext.automap.complaints at 0x2177919bb88>,
#  <sqlalchemy.ext.automap.complaints at 0x2177919bc88>,
#  <sqlalchemy.ext.automap.complaints at 0x2177919bd88>,
#  <sqlalchemy.ext.automap.complaints at 0x2177919be88>,
#  <sqlalchemy.ext.automap.complaints at 0x2177919bf88>,
#  <sqlalchemy.ext.automap.complaints at 0x2177941a0c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2177941a1c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2177941a2c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2177941a3c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2177941a4c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2177941a5c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2177941a6c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2177941a7c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2177941a8c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2177941a9c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2177941aac8>,
#  <sqlalchemy.ext.automap.complaints at 0x2177941abc8>,
#  <sqlalchemy.ext.automap.complaints at 0x2177941acc8>,
#  <sqlalchemy.ext.automap.complaints at 0x2177941adc8>,
#  <sqlalchemy.ext.automap.complaints at 0x2177941aec8>,
#  <sqlalchemy.ext.automap.complaints at 0x2177941afc8>,
#  <sqlalchemy.ext.automap.complaints at 0x21779590108>,
#  <sqlalchemy.ext.automap.complaints at 0x21779590208>,
#  <sqlalchemy.ext.automap.complaints at 0x21779590308>,
#  <sqlalchemy.ext.automap.complaints at 0x21779590408>,
#  <sqlalchemy.ext.automap.complaints at 0x21779590508>,
#  <sqlalchemy.ext.automap.complaints at 0x21779590608>,
#  <sqlalchemy.ext.automap.complaints at 0x21779590708>,
#  <sqlalchemy.ext.automap.complaints at 0x21779590808>,
#  <sqlalchemy.ext.automap.complaints at 0x21779590908>,
#  <sqlalchemy.ext.automap.complaints at 0x21779590a08>,
#  <sqlalchemy.ext.automap.complaints at 0x21779590b08>,
#  <sqlalchemy.ext.automap.complaints at 0x21779590c08>,
#  <sqlalchemy.ext.automap.complaints at 0x21779590d08>,
#  <sqlalchemy.ext.automap.complaints at 0x21779590e08>,
#  <sqlalchemy.ext.automap.complaints at 0x21779590f08>,
#  <sqlalchemy.ext.automap.complaints at 0x21779749048>,
#  <sqlalchemy.ext.automap.complaints at 0x21779749148>,
#  <sqlalchemy.ext.automap.complaints at 0x21779749248>,
#  <sqlalchemy.ext.automap.complaints at 0x21779749348>,
#  <sqlalchemy.ext.automap.complaints at 0x21779749448>,
#  <sqlalchemy.ext.automap.complaints at 0x21779749548>,
#  <sqlalchemy.ext.automap.complaints at 0x21779749648>,
#  <sqlalchemy.ext.automap.complaints at 0x21779749748>,
#  <sqlalchemy.ext.automap.complaints at 0x21779749848>,
#  <sqlalchemy.ext.automap.complaints at 0x21779749948>,
#  <sqlalchemy.ext.automap.complaints at 0x21779749a48>,
#  <sqlalchemy.ext.automap.complaints at 0x21779749b48>,
#  <sqlalchemy.ext.automap.complaints at 0x21779749c48>,
#  <sqlalchemy.ext.automap.complaints at 0x21779749d48>,
#  <sqlalchemy.ext.automap.complaints at 0x21779749e48>,
#  <sqlalchemy.ext.automap.complaints at 0x21779749f48>,
#  <sqlalchemy.ext.automap.complaints at 0x217798dc088>,
#  <sqlalchemy.ext.automap.complaints at 0x217798dc188>,
#  <sqlalchemy.ext.automap.complaints at 0x217798dc288>,
#  <sqlalchemy.ext.automap.complaints at 0x217798dc388>,
#  <sqlalchemy.ext.automap.complaints at 0x217798dc488>,
#  <sqlalchemy.ext.automap.complaints at 0x217798dc588>,
#  <sqlalchemy.ext.automap.complaints at 0x217798dc688>,
#  <sqlalchemy.ext.automap.complaints at 0x217798dc788>,
#  <sqlalchemy.ext.automap.complaints at 0x217798dc888>,
#  <sqlalchemy.ext.automap.complaints at 0x217798dc988>,
#  <sqlalchemy.ext.automap.complaints at 0x217798dca88>,
#  <sqlalchemy.ext.automap.complaints at 0x217798dcb88>,
#  <sqlalchemy.ext.automap.complaints at 0x217798dcc88>,
#  <sqlalchemy.ext.automap.complaints at 0x217798dcd88>,
#  <sqlalchemy.ext.automap.complaints at 0x217798dce88>,
#  <sqlalchemy.ext.automap.complaints at 0x217798dcf88>,
#  <sqlalchemy.ext.automap.complaints at 0x21779ca00c8>,
#  <sqlalchemy.ext.automap.complaints at 0x21779ca01c8>,
#  <sqlalchemy.ext.automap.complaints at 0x21779ca02c8>,
#  <sqlalchemy.ext.automap.complaints at 0x21779ca03c8>,
#  <sqlalchemy.ext.automap.complaints at 0x21779ca04c8>,
#  <sqlalchemy.ext.automap.complaints at 0x21779ca05c8>,
#  <sqlalchemy.ext.automap.complaints at 0x21779ca06c8>,
#  <sqlalchemy.ext.automap.complaints at 0x21779ca07c8>,
#  <sqlalchemy.ext.automap.complaints at 0x21779ca08c8>,
#  <sqlalchemy.ext.automap.complaints at 0x21779ca09c8>,
#  <sqlalchemy.ext.automap.complaints at 0x21779ca0ac8>,
#  <sqlalchemy.ext.automap.complaints at 0x21779ca0bc8>,
#  <sqlalchemy.ext.automap.complaints at 0x21779ca0cc8>,
#  <sqlalchemy.ext.automap.complaints at 0x21779ca0dc8>,
#  <sqlalchemy.ext.automap.complaints at 0x21779ca0ec8>,
#  <sqlalchemy.ext.automap.complaints at 0x21779ca0fc8>,
#  <sqlalchemy.ext.automap.complaints at 0x21779dc9108>,
#  <sqlalchemy.ext.automap.complaints at 0x21779dc9208>,
#  <sqlalchemy.ext.automap.complaints at 0x21779dc9308>,
#  <sqlalchemy.ext.automap.complaints at 0x21779dc9408>,
#  <sqlalchemy.ext.automap.complaints at 0x21779dc9508>,
#  <sqlalchemy.ext.automap.complaints at 0x21779dc9608>,
#  <sqlalchemy.ext.automap.complaints at 0x21779dc9708>,
#  <sqlalchemy.ext.automap.complaints at 0x21779dc9808>,
#  <sqlalchemy.ext.automap.complaints at 0x21779dc9908>,
#  <sqlalchemy.ext.automap.complaints at 0x21779dc9a08>,
#  <sqlalchemy.ext.automap.complaints at 0x21779dc9b08>,
#  <sqlalchemy.ext.automap.complaints at 0x21779dc9c08>,
#  <sqlalchemy.ext.automap.complaints at 0x21779dc9d08>,
#  <sqlalchemy.ext.automap.complaints at 0x21779dc9e08>,
#  <sqlalchemy.ext.automap.complaints at 0x21779dc9f08>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a010048>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a010148>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a010248>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a010348>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a010448>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a010548>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a010648>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a010748>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a010848>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a010948>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a010a48>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a010b48>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a010c48>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a010d48>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a010e48>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a010f48>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a1a5088>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a1a5188>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a1a5288>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a1a5388>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a1a5488>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a1a5588>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a1a5688>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a1a5788>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a1a5888>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a1a5988>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a1a5a88>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a1a5b88>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a1a5c88>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a1a5d88>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a1a5e88>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a1a5f88>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a2c60c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a2c61c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a2c62c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a2c63c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a2c64c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a2c65c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a2c66c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a2c67c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a2c68c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a2c69c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a2c6ac8>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a2c6bc8>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a2c6cc8>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a2c6dc8>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a2c6ec8>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a2c6fc8>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a58a108>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a58a208>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a58a308>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a58a408>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a58a508>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a58a608>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a58a708>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a58a808>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a58a908>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a58aa08>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a58ab08>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a58ac08>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a58ad08>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a58ae08>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a58af08>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a7a7048>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a7a7148>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a7a7248>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a7a7348>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a7a7448>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a7a7548>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a7a7648>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a7a7748>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a7a7848>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a7a7948>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a7a7a48>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a7a7b48>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a7a7c48>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a7a7d48>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a7a7e48>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a7a7f48>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a966088>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a966188>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a966288>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a966388>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a966488>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a966588>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a966688>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a966788>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a966888>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a966988>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a966a88>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a966b88>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a966c88>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a966d88>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a966e88>,
#  <sqlalchemy.ext.automap.complaints at 0x2177a966f88>,
#  <sqlalchemy.ext.automap.complaints at 0x2177aad20c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2177aad21c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2177aad22c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2177aad23c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2177aad24c8>,
#  <sqlalchemy.ext.automap.complaints at 0x2177aad25c8>,
#  ...]

# %%
sel2 = [Complaints.submitted_via, func.count(Complaints.submitted_via)]
data2 = session.query(*sel2).group_by(Complaints.submitted_via).all()
data2

# %%
type(data1)
# Out:
# list

# %%
app = Flask(__name__)

# %%
@app.route("/")
def index() :
    return " Project 3"

@app.route("/Productdata")
def Productdata() :
    return data1

@app.route("/Submitteddata")
def Submitteddata() :
    return data2

# %%
if __name__ == "__main__":
    app.run(debug=True)
