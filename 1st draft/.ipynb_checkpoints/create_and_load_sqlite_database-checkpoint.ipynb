# %%
from sqlalchemy import create_engine, Column, Integer, String, Date
import pandas
from sqlalchemy.ext.declarative import declarative_base

# %%
# Create our database engine
engine = create_engine('sqlite:///../Resources/complaints.sqlite')

# %%
# Read data from CSV and load into a dataframe object
data = pandas.read_csv('../Resources/cleaned.csv')
 
# Write data into the table in PostgreSQL database
data.to_sql('complaints',engine, if_exists = "append", index = False)
# Out:
# 925182

# %%
# test to see if the data was uploaded
engine.execute('select * from complaints').fetchall()
# Out:
# [('04/07/22', 'Debt collection', 'Credit card debt', 'Attempts to collect debt not owed', 'Debt was result of identity theft', 'Colony Brands, Inc.', 'AL', '36037', 'Consent provided', 'Web', '04/27/22', 'Closed with explanation', 'Yes', 5420254),
#  ('09/15/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', "Credit inquiries on your report that you don't recognize", 'EQUIFAX, INC.', 'TX', '76140', 'Consent not provided', 'Web', '09/15/22', 'Closed with explanation', 'Yes', 5986208),
#  ('07/19/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'TX', '76542', 'Consent provided', 'Web', '07/19/22', 'Closed with non-monetary relief', 'Yes', 5788326),
#  ('07/19/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Their investigation did not fix an error on your report', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'AZ', '85021', 'Consent provided', 'Web', '07/19/22', 'Closed with non-monetary relief', 'Yes', 5788205),
#  ('04/07/22', 'Credit card or prepaid card', 'Government benefit card', 'Problem with a purchase or transfer', 'Charged for a purchase or transfer you did not make with the card', 'U.S. BANCORP', 'TX', '78227', 'Consent provided', 'Web', '04/07/22', 'Closed with monetary relief', 'Yes', 5420425),
#  ('03/13/23', 'Debt collection', 'I do not know', 'Attempts to collect debt not owed', 'Debt is not yours', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'CA', '94518', 'None', 'Web', '03/13/23', 'In progress', 'Yes', 6685760),
#  ('04/07/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Account information incorrect', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'TN', '37211', 'Consent not provided', 'Web', '04/07/22', 'Closed with non-monetary relief', 'Yes', 5420710),
#  ('10/03/22', 'Debt collection', 'Payday loan debt', 'Attempts to collect debt not owed', 'Debt is not yours', 'CCF Intermediate Holdings LLC', 'LA', '71108', 'Consent not provided', 'Web', '10/24/22', 'Closed with explanation', 'Yes', 6046384),
#  ('07/20/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', "Credit inquiries on your report that you don't recognize", 'EQUIFAX, INC.', 'GA', '31322', 'Consent provided', 'Web', '07/20/22', 'Closed with explanation', 'Yes', 5788603),
#  ('04/07/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Information belongs to someone else', 'EQUIFAX, INC.', 'TX', '75071', 'Consent provided', 'Web', '04/07/22', 'Closed with explanation', 'Yes', 5420542),
#  ('04/07/22', 'Debt collection', 'Other debt', 'False statements or representation', 'Indicated you were committing crime by not paying debt', 'The CMI Group, Inc.', 'CA', '95812', 'Consent provided', 'Web', '04/26/22', 'Closed with explanation', 'Yes', 5419865),
#  ('09/15/22', 'Student loan', 'Federal student loan servicing', 'Dealing with your lender or servicer', 'Trouble with how payments are being handled', 'EdFinancial Services', 'PA', '16137', 'Consent provided', 'Web', '09/15/22', 'Closed with explanation', 'Yes', 5986223),
#  ('09/15/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Information belongs to someone else', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'TN', '37840', 'Consent provided', 'Web', '09/15/22', 'Closed with non-monetary relief', 'Yes', 5986340),
#  ('09/15/22', 'Checking or savings account', 'Other banking product or service', 'Managing an account', 'Banking errors', 'Atlantic Union Bankshares, Inc.', 'TN', '38118', 'Consent provided', 'Web', '10/06/22', 'Closed with non-monetary relief', 'Yes', 5986122),
#  ('02/14/23', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', "Credit inquiries on your report that you don't recognize", 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'KY', '40515', 'Consent not provided', 'Web', '02/14/23', 'Closed with non-monetary relief', 'Yes', 6569776),
#  ('09/15/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Information belongs to someone else', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'IL', '60643', 'Consent provided', 'Web', '09/15/22', 'Closed with non-monetary relief', 'Yes', 5986356),
#  ('04/07/22', 'Money transfer, virtual currency, or money service', 'Virtual currency', 'Other service problem', 'None', 'Winklevoss Exchange LLC', 'FL', '33180', 'Consent provided', 'Web', '04/07/22', 'Closed with explanation', 'Yes', 5420562),
#  ('07/19/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', "Credit inquiries on your report that you don't recognize", 'BMW Financial Services NA, LLC', 'TX', '75230', 'Consent not provided', 'Web', '07/19/22', 'Closed with explanation', 'Yes', 5788006),
#  ('04/11/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Was not notified of investigation status or results', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'FL', '32256', 'Consent not provided', 'Web', '04/11/22', 'Closed with explanation', 'Yes', 5432121),
#  ('07/19/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Their investigation did not fix an error on your report', 'Experian Information Solutions Inc.', 'GA', '30277', 'Consent provided', 'Web', '07/19/22', 'Closed with explanation', 'Yes', 5788022),
#  ('09/15/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Information belongs to someone else', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'NV', '89084', 'Consent provided', 'Web', '09/15/22', 'Closed with non-monetary relief', 'Yes', 5986370),
#  ('07/19/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'TX', '76542', 'Consent provided', 'Web', '07/19/22', 'Closed with non-monetary relief', 'Yes', 5788041),
#  ('09/15/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Information belongs to someone else', 'Experian Information Solutions Inc.', 'IL', '60069', 'Consent not provided', 'Web', '09/15/22', 'Closed with explanation', 'Yes', 5986376),
#  ('09/15/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Information belongs to someone else', 'EQUIFAX, INC.', 'IL', '60653', 'Consent provided', 'Web', '09/15/22', 'Closed with explanation', 'Yes', 5986464),
#  ('09/15/22', 'Checking or savings account', 'Checking account', 'Managing an account', 'Funds not handled or disbursed as instructed', 'BANK OF THE WEST', 'CA', '90038', None, 'Referral', '09/16/22', 'Closed with monetary relief', 'Yes', 5989787),
#  ('04/07/22', 'Debt collection', 'Credit card debt', 'Attempts to collect debt not owed', 'Debt is not yours', 'ENCORE CAPITAL GROUP INC.', 'FL', '34787', 'Consent provided', 'Web', '04/07/22', 'Closed with explanation', 'Yes', 5420063),
#  ('09/15/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Their investigation did not fix an error on your report', 'Experian Information Solutions Inc.', 'GA', '30034', 'Consent not provided', 'Web', '09/15/22', 'Closed with explanation', 'Yes', 5985900),
#  ('10/03/22', 'Money transfer, virtual currency, or money service', 'International money transfer', 'Other transaction problem', 'None', 'CITIZENS FINANCIAL GROUP, INC.', 'PA', '15145', 'Consent not provided', 'Web', '10/20/22', 'Closed with explanation', 'Yes', 6046773),
#  ('07/19/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Was not notified of investigation status or results', 'Experian Information Solutions Inc.', 'GA', '30349', 'Consent provided', 'Web', '07/19/22', 'Closed with explanation', 'Yes', 5788454),
#  ('12/28/22', 'Money transfer, virtual currency, or money service', 'Virtual currency', 'Fraud or scam', 'None', 'CONST LLC', 'MD', '20854', 'Consent provided', 'Web', '01/19/23', 'Untimely response', 'No', 6365434),
#  ('07/19/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'NC', '27591', 'Consent not provided', 'Web', '07/19/22', 'Closed with explanation', 'Yes', 5788383),
#  ('09/15/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'EQUIFAX, INC.', 'FL', '33414', 'Consent not provided', 'Web', '09/15/22', 'Closed with explanation', 'Yes', 5985802),
#  ('10/03/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Information belongs to someone else', 'Experian Information Solutions Inc.', 'FL', '33026', 'Consent not provided', 'Web', '10/03/22', 'Closed with explanation', 'Yes', 6042246),
#  ('09/15/22', 'Debt collection', 'Other debt', 'Attempts to collect debt not owed', 'Debt is not yours', 'Experian Information Solutions Inc.', 'MN', '55404', 'Consent not provided', 'Web', '09/15/22', 'Closed with non-monetary relief', 'Yes', 5986405),
#  ('04/07/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Problem with personal statement of dispute', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'None', 'None', 'Consent provided', 'Web', '04/07/22', 'Closed with explanation', 'Yes', 5419771),
#  ('07/19/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'EQUIFAX, INC.', 'FL', '33067', 'Consent not provided', 'Web', '07/19/22', 'Closed with explanation', 'Yes', 5788358),
#  ('04/07/22', 'Checking or savings account', 'Checking account', 'Managing an account', 'Problem accessing account', 'TD BANK US HOLDING COMPANY', 'CT', '06278', 'Consent provided', 'Web', '04/07/22', 'Closed with monetary relief', 'Yes', 5419951),
#  ('09/15/22', 'Checking or savings account', 'Checking account', 'Managing an account', 'Problem using a debit or ATM card', 'Chime Financial Inc', 'AL', '35235', 'Consent provided', 'Web', '09/15/22', 'Closed with explanation', 'Yes', 5986495),
#  ('07/19/22', 'Debt collection', 'I do not know', 'Attempts to collect debt not owed', 'Debt is not yours', 'Credence Resource Management, LLC', 'NY', '11226', 'Consent provided', 'Web', '08/02/22', 'Closed with non-monetary relief', 'Yes', 5788407),
#  ('09/15/22', 'Credit card or prepaid card', 'General-purpose credit card or charge card', "Problem with a credit reporting company's investigation into an existing problem", 'Their investigation did not fix an error on your report', 'DISCOVER BANK', 'GA', '30022', None, 'Referral', '09/15/22', 'Closed with explanation', 'Yes', 5985481),
#  ('07/11/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Information belongs to someone else', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'TN', '37042', 'Consent provided', 'Web', '07/11/22', 'Closed with non-monetary relief', 'Yes', 5756363),
#  ('02/19/23', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'NJ', '08060', 'Consent not provided', 'Web', '02/19/23', 'Closed with non-monetary relief', 'Yes', 6591407),
#  ('04/07/22', 'Debt collection', 'Credit card debt', 'Attempts to collect debt not owed', 'Debt was result of identity theft', 'ENCORE CAPITAL GROUP INC.', 'AZ', '85119', 'Consent provided', 'Web', '04/07/22', 'Closed with explanation', 'Yes', 5419347),
#  ('03/23/23', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'Experian Information Solutions Inc.', 'FL', '33312', 'None', 'Web', '03/23/23', 'In progress', 'Yes', 6742401),
#  ('12/07/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'EQUIFAX, INC.', 'TX', '76013', 'Consent not provided', 'Web', '12/07/22', 'Closed with explanation', 'Yes', 6290785),
#  ('07/19/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'Experian Information Solutions Inc.', 'FL', '33067', 'Consent not provided', 'Web', '07/19/22', 'Closed with explanation', 'Yes', 5788318),
#  ('07/19/22', 'Debt collection', 'Other debt', 'Attempts to collect debt not owed', 'Debt was result of identity theft', 'Rowland Avenue Management, Inc. A/KA Columbia Debt Recovery, LLC d/b/a Genesis', 'FL', '32828', 'Consent provided', 'Web', '07/19/22', 'Closed with explanation', 'Yes', 5788334),
#  ('09/15/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'LA', '71108', 'Consent not provided', 'Web', '09/15/22', 'Closed with non-monetary relief', 'Yes', 5983874),
#  ('04/07/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'Radius Global Solutions LLC', 'OH', '44120', 'Consent not provided', 'Web', '04/07/22', 'Closed with explanation', 'Yes', 5420208),
#  ('09/15/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Investigation took more than 30 days', 'EQUIFAX, INC.', 'FL', '32789', 'Consent not provided', 'Web', '09/15/22', 'Closed with explanation', 'Yes', 5983875),
#  ('09/15/22', 'Debt collection', 'Credit card debt', 'Attempts to collect debt not owed', 'Debt was paid', 'SYNCHRONY FINANCIAL', 'GA', '30906', 'Consent provided', 'Web', '09/15/22', 'Closed with monetary relief', 'Yes', 5987579),
#  ('09/15/22', 'Checking or savings account', 'Checking account', 'Managing an account', 'Deposits and withdrawals', 'M&T BANK CORPORATION', 'CT', '06062', 'Consent provided', 'Web', '09/15/22', 'Closed with explanation', 'Yes', 5983739),
#  ('04/07/22', 'Debt collection', 'Auto debt', 'Attempts to collect debt not owed', 'Debt was result of identity theft', 'ALLY FINANCIAL INC.', 'None', 'None', 'Consent not provided', 'Web', '04/07/22', 'Closed with explanation', 'Yes', 5419564),
#  ('02/05/23', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Their investigation did not fix an error on your report', 'Experian Information Solutions Inc.', 'MA', '01840', 'Consent provided', 'Web', '02/05/23', 'Closed with explanation', 'Yes', 6524290),
#  ('09/15/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Their investigation did not fix an error on your report', 'Experian Information Solutions Inc.', 'MI', '48340', 'Consent provided', 'Web', '09/15/22', 'Closed with explanation', 'Yes', 5983905),
#  ('11/13/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Their investigation did not fix an error on your report', 'Experian Information Solutions Inc.', 'TX', '75232', 'Consent not provided', 'Web', '11/13/22', 'Closed with explanation', 'Yes', 6199484),
#  ('01/02/23', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'Experian Information Solutions Inc.', 'CT', '06604', 'Consent not provided', 'Web', '01/02/23', 'Closed with explanation', 'Yes', 6388961),
#  ('09/15/22', 'Money transfer, virtual currency, or money service', 'Refund anticipation check', 'Lost or stolen check', 'None', 'JPMORGAN CHASE & CO.', 'NY', '11361', 'Consent provided', 'Web', '09/15/22', 'Closed with explanation', 'Yes', 5986972),
#  ('06/07/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'EQUIFAX, INC.', 'MS', '39046', 'Consent not provided', 'Web', '06/07/22', 'Closed with explanation', 'Yes', 5642692),
#  ('07/19/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Information belongs to someone else', 'Experian Information Solutions Inc.', 'NC', '27104', 'Consent provided', 'Web', '07/19/22', 'Closed with non-monetary relief', 'Yes', 5788412),
#  ('04/11/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Other personal consumer report', 'Identity theft protection or other monitoring services', 'Problem canceling credit monitoring or identify theft protection service', 'Skrill USA, Inc.', 'WA', '98030', 'Consent provided', 'Web', '04/26/22', 'Closed with explanation', 'No', 5429876),
#  ('09/15/22', 'Debt collection', 'Medical debt', 'Attempts to collect debt not owed', 'Debt was paid', 'LANIER COLLECTIONS AGENCY AND SERVICES INC', 'TX', '78204', 'Consent not provided', 'Web', '09/15/22', 'Closed with explanation', 'Yes', 5983992),
#  ('04/07/22', 'Debt collection', 'I do not know', 'Attempts to collect debt not owed', 'Debt is not yours', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'TX', '77372', None, 'Phone', '04/25/22', 'Closed with non-monetary relief', 'Yes', 5420201),
#  ('04/07/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Information belongs to someone else', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'NC', '27589', 'Consent not provided', 'Web', '04/07/22', 'Closed with non-monetary relief', 'Yes', 5419373),
#  ('07/19/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Their investigation did not fix an error on your report', 'CITIBANK, N.A.', 'NC', '28078', 'Consent provided', 'Web', '07/19/22', 'Closed with explanation', 'Yes', 5788370),
#  ('09/15/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', "Credit inquiries on your report that you don't recognize", 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'FL', '33169', 'Consent provided', 'Web', '09/15/22', 'Closed with non-monetary relief', 'Yes', 5984036),
#  ('02/05/23', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Was not notified of investigation status or results', 'Experian Information Solutions Inc.', 'CA', '94587', 'Consent not provided', 'Web', '02/05/23', 'Closed with explanation', 'Yes', 6524329),
#  ('06/26/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Their investigation did not fix an error on your report', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'MA', '01118', 'Consent provided', 'Web', '06/26/22', 'Closed with non-monetary relief', 'Yes', 5710791),
#  ('04/07/22', 'Checking or savings account', 'Other banking product or service', 'Closing an account', 'Funds not received from closed account', 'WELLS FARGO & COMPANY', 'FL', '34481', 'Consent provided', 'Web', '04/07/22', 'Closed with explanation', 'Yes', 5419688),
#  ('04/07/22', 'Debt collection', 'I do not know', 'Written notification about debt', "Didn't receive notice of right to dispute", 'HCFS Health Care Financial Services, Inc.', 'FL', '33169', 'Other', 'Web', '04/07/22', 'Closed with explanation', 'No', 5419349),
#  ('04/07/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Account information incorrect', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'NY', '10065', 'Consent not provided', 'Web', '04/07/22', 'Closed with explanation', 'Yes', 5418916),
#  ('04/07/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'CA', '92377', 'Consent provided', 'Web', '04/07/22', 'Closed with non-monetary relief', 'Yes', 5418894),
#  ('04/07/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Was not notified of investigation status or results', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'FL', '32909', 'Consent provided', 'Web', '04/07/22', 'Closed with non-monetary relief', 'Yes', 5418892),
#  ('07/19/22', 'Checking or savings account', 'Checking account', 'Closing an account', "Can't close your account", 'UNITED SERVICES AUTOMOBILE ASSOCIATION', 'AL', '36502', 'Consent provided', 'Web', '07/19/22', 'Closed with explanation', 'Yes', 5788289),
#  ('07/03/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'AmeriCollect', 'FL', '32202', 'Consent not provided', 'Web', '07/03/22', 'Closed with explanation', 'Yes', 5731650),
#  ('09/29/22', 'Checking or savings account', 'Checking account', 'Managing an account', 'Fee problem', 'REGIONS FINANCIAL CORPORATION', 'FL', '32311', 'Consent not provided', 'Web', '09/29/22', 'Closed with explanation', 'Yes', 6031338),
#  ('12/21/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Information belongs to someone else', 'EQUIFAX, INC.', 'FL', '33301', 'Other', 'Web', '12/21/22', 'Closed with explanation', 'Yes', 6345884),
#  ('04/11/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Their investigation did not fix an error on your report', 'EQUIFAX, INC.', 'GA', '30274', 'Consent not provided', 'Web', '04/11/22', 'Closed with explanation', 'Yes', 5432788),
#  ('04/11/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Account information incorrect', 'Experian Information Solutions Inc.', 'MA', '01330', None, 'Phone', '04/11/22', 'Closed with explanation', 'Yes', 5431414),
#  ('04/07/22', 'Credit card or prepaid card', 'Store credit card', 'Problem when making payments', 'Problem during payment process', 'SYNCHRONY FINANCIAL', 'IL', '62881', 'Consent provided', 'Web', '04/07/22', 'Closed with explanation', 'Yes', 5419097),
#  ('09/25/22', 'Credit card or prepaid card', 'General-purpose credit card or charge card', 'Fees or interest', 'Problem with fees', 'CAPITAL ONE FINANCIAL CORPORATION', 'CT', '06126', 'Consent provided', 'Web', '09/25/22', 'Closed with explanation', 'Yes', 6016538),
#  ('04/07/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Account status incorrect', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'CA', '91764', 'Consent not provided', 'Web', '04/07/22', 'Closed with non-monetary relief', 'Yes', 5418544),
#  ('04/07/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Investigation took more than 30 days', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'TX', '78242', 'Consent not provided', 'Web', '04/07/22', 'Closed with non-monetary relief', 'Yes', 5418554),
#  ('04/07/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Account status incorrect', 'EQUIFAX, INC.', 'CA', '91764', 'Consent not provided', 'Web', '04/07/22', 'Closed with explanation', 'Yes', 5418542),
#  ('10/02/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'World Acceptance Corporation', 'SC', '29594', 'Consent provided', 'Web', '10/02/22', 'Closed with explanation', 'Yes', 6041115),
#  ('07/19/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Information belongs to someone else', 'EQUIFAX, INC.', 'GA', '30067', 'Consent provided', 'Web', '07/19/22', 'Closed with explanation', 'Yes', 5788231),
#  ('04/10/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'Experian Information Solutions Inc.', 'NJ', '08060', 'Consent not provided', 'Web', '04/10/22', 'Closed with explanation', 'Yes', 5430634),
#  ('04/07/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Information belongs to someone else', 'Experian Information Solutions Inc.', 'NY', '10002', 'Consent provided', 'Web', '04/07/22', 'Closed with explanation', 'Yes', 5418717),
#  ('04/07/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Old information reappears or never goes away', 'Experian Information Solutions Inc.', 'AL', '36274', 'Consent not provided', 'Web', '04/07/22', 'Closed with non-monetary relief', 'Yes', 5418325),
#  ('07/19/22', 'Debt collection', 'Credit card debt', 'Attempts to collect debt not owed', 'Debt was result of identity theft', 'PORTFOLIO RECOVERY ASSOCIATES INC', 'FL', '32202', 'Consent provided', 'Web', '07/19/22', 'Closed with explanation', 'Yes', 5787737),
#  ('04/07/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Information belongs to someone else', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'PA', '19104', None, 'Phone', '04/07/22', 'Closed with explanation', 'Yes', 5418585),
#  ('02/15/23', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Their investigation did not fix an error on your report', 'Experian Information Solutions Inc.', 'TX', '75025', 'Consent not provided', 'Web', '02/15/23', 'Closed with explanation', 'Yes', 6578342),
#  ('05/19/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Information belongs to someone else', 'Experian Information Solutions Inc.', 'MI', '48111', 'Consent provided', 'Web', '05/19/22', 'Closed with non-monetary relief', 'Yes', 5579564),
#  ('06/07/22', 'Mortgage', 'Conventional home mortgage', 'Trouble during payment process', 'None', 'NATIONSTAR MORTGAGE LLC', 'CO', '81623', 'Consent provided', 'Web', '06/07/22', 'Closed with explanation', 'Yes', 5640979),
#  ('04/07/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Their investigation did not fix an error on your report', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'TX', '77347', 'Consent not provided', 'Web', '04/07/22', 'Closed with non-monetary relief', 'Yes', 5418175),
#  ('04/07/22', 'Vehicle loan or lease', 'Loan', 'Struggling to pay your loan', 'Denied request to lower payments', 'CREDIT ACCEPTANCE CORPORATION', 'PA', '19012', 'Consent provided', 'Web', '04/07/22', 'Closed with explanation', 'Yes', 5419233),
#  ('04/07/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Information belongs to someone else', 'Experian Information Solutions Inc.', 'PA', '19153', 'Consent not provided', 'Web', '04/07/22', 'Closed with non-monetary relief', 'Yes', 5418105),
#  ('08/31/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Account status incorrect', 'Experian Information Solutions Inc.', 'MD', '21012', 'Consent provided', 'Web', '08/31/22', 'Closed with non-monetary relief', 'Yes', 5931468),
#  ('01/26/23', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Personal information incorrect', 'Experian Information Solutions Inc.', 'IL', '60647', 'Consent not provided', 'Web', '01/26/23', 'Closed with non-monetary relief', 'Yes', 6485592),
#  ('07/19/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Unable to get your credit report or credit score', 'Other problem getting your report or credit score', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'MA', '02360', 'Consent provided', 'Web', '07/19/22', 'Closed with non-monetary relief', 'Yes', 5787787),
#  ('02/16/23', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Information belongs to someone else', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'PA', '19050', 'Consent not provided', 'Web', '02/16/23', 'Closed with non-monetary relief', 'Yes', 6583606),
#  ('12/19/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Unable to get your credit report or credit score', 'Other problem getting your report or credit score', 'EQUIFAX, INC.', 'KS', '67205', 'Consent not provided', 'Web', '12/19/22', 'Closed with explanation', 'Yes', 6338857),
#  ('08/31/22', 'Money transfer, virtual currency, or money service', 'Mobile or digital wallet', 'Fraud or scam', 'None', 'BAM Management US Holdings Inc.', 'MI', '48126', 'Consent not provided', 'Web', '08/31/22', 'Closed with explanation', 'Yes', 5931477),
#  ('03/24/23', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Old information reappears or never goes away', 'Experian Information Solutions Inc.', 'CA', '92557', 'None', 'Web', '03/24/23', 'In progress', 'Yes', 6746464),
#  ('04/11/22', 'Money transfer, virtual currency, or money service', 'Mobile or digital wallet', 'Unauthorized transactions or other transaction problem', 'None', 'JPMORGAN CHASE & CO.', 'TX', '75248', None, 'Phone', '04/11/22', 'Closed with explanation', 'Yes', 5432059),
#  ('03/24/23', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Their investigation did not fix an error on your report', 'EQUIFAX, INC.', 'FL', '32837', 'None', 'Web', '03/24/23', 'In progress', 'Yes', 6743277),
#  ('03/07/23', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', "Credit inquiries on your report that you don't recognize", 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'OH', '45459', 'None', 'Web', '03/07/23', 'In progress', 'Yes', 6662400),
#  ('07/26/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Information belongs to someone else', 'Experian Information Solutions Inc.', 'AL', '35806', 'Consent not provided', 'Web', '07/26/22', 'Closed with non-monetary relief', 'Yes', 5812035),
#  ('02/07/23', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Their investigation did not fix an error on your report', 'TRANSWORLD SYSTEMS INC', 'CA', '95693', 'Consent not provided', 'Web', '02/07/23', 'Closed with explanation', 'Yes', 6541621),
#  ('04/10/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Information belongs to someone else', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'AL', '35215', 'Consent not provided', 'Web', '04/10/22', 'Closed with non-monetary relief', 'Yes', 5429117),
#  ('02/07/23', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Investigation took more than 30 days', 'EQUIFAX, INC.', 'NC', '27406', 'Consent not provided', 'Web', '02/07/23', 'Closed with explanation', 'Yes', 6542124),
#  ('04/07/22', 'Money transfer, virtual currency, or money service', 'Domestic (US) money transfer', 'Fraud or scam', 'None', 'BANK OF AMERICA, NATIONAL ASSOCIATION', 'NC', '27410', 'Consent provided', 'Web', '04/07/22', 'Closed with explanation', 'Yes', 5418047),
#  ('07/19/22', 'Debt collection', 'Auto debt', 'Communication tactics', 'Used obscene, profane, or other abusive language', 'TriVerity, Inc.', 'MN', '55804', 'Consent provided', 'Web', '07/19/22', 'Closed with explanation', 'Yes', 5787967),
#  ('02/07/23', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', "Credit inquiries on your report that you don't recognize", 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'FL', '32825', 'Consent not provided', 'Web', '02/07/23', 'Closed with non-monetary relief', 'Yes', 6542125),
#  ('05/19/22', 'Debt collection', 'Other debt', 'Attempts to collect debt not owed', 'Debt is not yours', 'Collection Bureau of the Hudson Valley, Inc.', 'NJ', '08057', 'Consent not provided', 'Web', '05/19/22', 'Closed with explanation', 'Yes', 5579584),
#  ('07/23/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'EQUIFAX, INC.', 'CA', '93274', 'Consent not provided', 'Web', '07/23/22', 'Closed with explanation', 'Yes', 5803178),
#  ('07/19/22', 'Vehicle loan or lease', 'Loan', 'Struggling to pay your loan', 'Denied request to lower payments', 'Porsche Financial Services, Inc.', 'IL', '60462', 'Consent provided', 'Web', '07/19/22', 'Closed with explanation', 'Yes', 5787822),
#  ('03/06/23', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Their investigation did not fix an error on your report', 'EQUIFAX, INC.', 'NY', '11415', 'None', 'Web', '03/06/23', 'Closed with explanation', 'Yes', 6654417),
#  ('02/15/23', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Account status incorrect', 'Mid-South Adjustment Co., Inc.', 'LA', '71270', 'Consent provided', 'Web', '02/15/23', 'Closed with explanation', 'Yes', 6577574),
#  ('04/07/22', 'Mortgage', 'FHA mortgage', 'Trouble during payment process', 'None', 'Ocwen Financial Corporation', 'TX', '78240', 'Consent provided', 'Web', '04/07/22', 'Closed with explanation', 'Yes', 5417833),
#  ('04/07/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Investigation took more than 30 days', 'EQUIFAX, INC.', 'TX', '75115', 'Consent provided', 'Web', '04/07/22', 'Closed with explanation', 'Yes', 5417768),
#  ('09/23/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'TX', '77084', 'Consent not provided', 'Web', '09/23/22', 'Closed with non-monetary relief', 'Yes', 6006964),
#  ('08/31/22', 'Checking or savings account', 'Checking account', 'Problem with a lender or other company charging your account', 'Transaction was not authorized', 'BANK OF AMERICA, NATIONAL ASSOCIATION', 'CA', '94545', 'Consent provided', 'Web', '08/31/22', 'Closed with monetary relief', 'Yes', 5931330),
#  ('07/26/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Their investigation did not fix an error on your report', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'FL', '34761', 'Consent not provided', 'Web', '07/26/22', 'Closed with non-monetary relief', 'Yes', 5814585),
#  ('08/31/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Their investigation did not fix an error on your report', 'EQUIFAX, INC.', 'PA', '19141', 'Other', 'Web', '08/31/22', 'Closed with explanation', 'Yes', 5931482),
#  ('04/07/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Their investigation did not fix an error on your report', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'VA', '23325', 'Consent not provided', 'Web', '04/07/22', 'Closed with non-monetary relief', 'Yes', 5418066),
#  ('04/07/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Account information incorrect', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'OH', '44708', 'Consent provided', 'Web', '04/07/22', 'Closed with non-monetary relief', 'Yes', 5418448),
#  ('08/30/22', 'Credit card or prepaid card', 'General-purpose credit card or charge card', 'Problem with a purchase shown on your statement', 'Card was charged for something you did not purchase with the card', 'Self Financial Inc.', 'PA', '19023', 'Consent provided', 'Web', '08/31/22', 'Closed with explanation', 'Yes', 5931537),
#  ('02/07/23', 'Debt collection', 'Credit card debt', 'Attempts to collect debt not owed', 'Debt is not yours', 'BANK OF AMERICA, NATIONAL ASSOCIATION', 'AR', '71901', 'Consent provided', 'Web', '02/07/23', 'Closed with explanation', 'Yes', 6542256),
#  ('05/19/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', "Credit inquiries on your report that you don't recognize", 'Experian Information Solutions Inc.', 'KY', '40206', 'Consent provided', 'Web', '05/19/22', 'Closed with explanation', 'Yes', 5578868),
#  ('08/30/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', "Credit inquiries on your report that you don't recognize", 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'NC', '28570', 'Other', 'Web', '08/30/22', 'Closed with non-monetary relief', 'Yes', 5932427),
#  ('02/04/23', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Their investigation did not fix an error on your report', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'CA', '91403', 'Consent not provided', 'Web', '02/04/23', 'Closed with non-monetary relief', 'Yes', 6523513),
#  ('01/23/23', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Account status incorrect', 'EQUIFAX, INC.', 'IL', '60637', 'Consent not provided', 'Web', '01/23/23', 'Closed with explanation', 'Yes', 6477312),
#  ('04/07/22', 'Mortgage', 'VA mortgage', 'Struggling to pay mortgage', 'None', 'WELLS FARGO & COMPANY', 'GA', '30248', 'Consent provided', 'Web', '04/07/22', 'Closed with explanation', 'Yes', 5418114),
#  ('09/14/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'EQUIFAX, INC.', 'GA', '30504', 'Consent provided', 'Web', '09/14/22', 'Closed with explanation', 'Yes', 5981314),
#  ('02/15/23', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', "Credit inquiries on your report that you don't recognize", 'EQUIFAX, INC.', 'GA', '30328', 'Consent provided', 'Web', '02/15/23', 'Closed with explanation', 'Yes', 6577744),
#  ('03/13/23', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Their investigation did not fix an error on your report', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'GA', '30297', 'None', 'Web', '03/13/23', 'In progress', 'Yes', 6685930),
#  ('07/19/22', 'Checking or savings account', 'Checking account', 'Opening an account', 'Unable to open an account', 'GOLDMAN SACHS BANK USA', 'CA', '92805', None, 'Referral', '07/20/22', 'Closed with explanation', 'Yes', 5793300),
#  ('01/31/23', 'Debt collection', 'I do not know', 'Attempts to collect debt not owed', 'Debt is not yours', 'TrueAccord Corp.', 'FL', '33346', 'Consent not provided', 'Web', '01/31/23', 'Closed with explanation', 'Yes', 6509846),
#  ('04/07/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Information belongs to someone else', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'TN', '38103', 'Consent not provided', 'Web', '04/07/22', 'Closed with non-monetary relief', 'Yes', 5417846),
#  ('06/27/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'Experian Information Solutions Inc.', 'SC', '29590', 'Consent not provided', 'Web', '06/27/22', 'Closed with explanation', 'Yes', 5712359),
#  ('04/07/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Information belongs to someone else', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'PA', '19026', 'Consent not provided', 'Web', '04/07/22', 'Closed with non-monetary relief', 'Yes', 5417787),
#  ('03/28/23', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'Experian Information Solutions Inc.', 'GA', '31632', 'None', 'Web', '03/28/23', 'In progress', 'Yes', 6766425),
#  ('09/14/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Account information incorrect', 'EQUIFAX, INC.', 'NJ', '07017', 'Consent provided', 'Web', '09/14/22', 'Closed with explanation', 'Yes', 5981316),
#  ('07/19/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'EQUIFAX, INC.', 'CA', '92655', 'Consent provided', 'Web', '07/19/22', 'Closed with explanation', 'Yes', 5788079),
#  ('04/07/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'Experian Information Solutions Inc.', 'NY', '13501', 'Consent provided', 'Web', '04/07/22', 'Closed with non-monetary relief', 'Yes', 5422348),
#  ('07/19/22', 'Money transfer, virtual currency, or money service', 'Mobile or digital wallet', 'Fraud or scam', 'None', 'WELLS FARGO & COMPANY', 'NY', '11213', 'Consent provided', 'Web', '07/19/22', 'Closed with explanation', 'Yes', 5788206),
#  ('09/23/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Their investigation did not fix an error on your report', 'Experian Information Solutions Inc.', 'NC', '27846', 'Consent provided', 'Web', '09/23/22', 'Closed with explanation', 'Yes', 6006967),
#  ('04/07/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Investigation took more than 30 days', 'Experian Information Solutions Inc.', 'AR', '72364', None, 'Phone', '04/07/22', 'Closed with explanation', 'Yes', 5422157),
#  ('04/07/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Public record information inaccurate', 'EQUIFAX, INC.', 'UT', '84047', 'Consent provided', 'Web', '04/07/22', 'Closed with explanation', 'Yes', 5422052),
#  ('07/19/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'PA', '19147', 'Consent provided', 'Web', '07/19/22', 'Closed with non-monetary relief', 'Yes', 5788254),
# ...
#  ('08/08/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', "Credit inquiries on your report that you don't recognize", 'ALLY FINANCIAL INC.', 'PA', '18201', 'Consent not provided', 'Web', '08/08/22', 'Closed with explanation', 'Yes', 5854935),
#  ('05/17/22', 'Debt collection', 'Credit card debt', 'False statements or representation', 'Attempted to collect wrong amount', 'Synovus Bank', 'IL', '62312', 'Consent provided', 'Web', '05/17/22', 'Closed with explanation', 'Yes', 5570438),
#  ('05/17/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'NJ', '07001', 'Consent provided', 'Web', '05/17/22', 'Closed with non-monetary relief', 'Yes', 5570127),
#  ('04/07/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Their investigation did not fix an error on your report', 'EQUIFAX, INC.', 'FL', '32208', 'Consent not provided', 'Web', '04/07/22', 'Closed with explanation', 'Yes', 5419576),
#  ('08/08/22', 'Money transfer, virtual currency, or money service', 'Virtual currency', 'Fraud or scam', 'None', 'JPMORGAN CHASE & CO.', 'CA', '94122', 'Other', 'Web', '08/08/22', 'Closed with explanation', 'Yes', 5856214),
#  ('04/07/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Their investigation did not fix an error on your report', 'Experian Information Solutions Inc.', 'NJ', '08757', 'Consent provided', 'Web', '04/07/22', 'Closed with explanation', 'Yes', 5419621),
#  ('05/17/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'Experian Information Solutions Inc.', 'AL', '36830', 'Consent not provided', 'Web', '05/17/22', 'Closed with non-monetary relief', 'Yes', 5570278),
#  ('04/07/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Their investigation did not fix an error on your report', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'TN', '38125', 'Consent not provided', 'Web', '04/07/22', 'Closed with non-monetary relief', 'Yes', 5419630),
#  ('04/07/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Other personal consumer report', 'Improper use of your report', 'Reporting company used your report improperly', 'Experian Information Solutions Inc.', 'NJ', '07017', 'Consent not provided', 'Web', '04/07/22', 'Closed with non-monetary relief', 'Yes', 5419689),
#  ('04/07/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Information belongs to someone else', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'PA', '19120', 'Consent not provided', 'Web', '04/07/22', 'Closed with non-monetary relief', 'Yes', 5419530),
#  ('02/10/23', 'Debt collection', 'Credit card debt', 'Attempts to collect debt not owed', 'Debt is not yours', 'ENCORE CAPITAL GROUP INC.', 'MA', '02703', 'Consent provided', 'Web', '02/10/23', 'Closed with non-monetary relief', 'Yes', 6551555),
#  ('05/17/22', 'Debt collection', 'I do not know', 'Attempts to collect debt not owed', 'Debt was already discharged in bankruptcy and is no longer owed', 'JPMORGAN CHASE & CO.', 'MO', '64093', 'Consent provided', 'Web', '05/17/22', 'Closed with explanation', 'Yes', 5571063),
#  ('05/17/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Their investigation did not fix an error on your report', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'GA', '30344', 'Consent not provided', 'Web', '05/17/22', 'Closed with non-monetary relief', 'Yes', 5570024),
#  ('05/15/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Their investigation did not fix an error on your report', 'Experian Information Solutions Inc.', 'MS', '38804', 'Consent provided', 'Web', '05/15/22', 'Closed with explanation', 'Yes', 5564048),
#  ('05/15/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'Experian Information Solutions Inc.', 'TN', '38008', 'Consent provided', 'Web', '05/15/22', 'Closed with non-monetary relief', 'Yes', 5564046),
#  ('05/17/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Their investigation did not fix an error on your report', 'OneMain Finance Corporation', 'MO', '63104', 'Consent provided', 'Web', '05/17/22', 'Closed with explanation', 'Yes', 5570089),
#  ('04/08/22', 'Mortgage', 'Conventional home mortgage', 'Trouble during payment process', 'None', 'PNC Bank N.A.', 'AZ', '85351', 'Consent provided', 'Web', '04/08/22', 'Closed with explanation', 'Yes', 5420676),
#  ('05/17/22', 'Payday loan, title loan, or personal loan', 'Payday loan', "Can't stop withdrawals from your bank account", 'None', 'Five Clans Lending LLC', 'OH', '44147', 'Consent provided', 'Web', '05/17/22', 'Closed with explanation', 'Yes', 5570051),
#  ('04/07/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'EQUIFAX, INC.', 'OR', '97304', 'Consent provided', 'Web', '04/07/22', 'Closed with explanation', 'Yes', 5419500),
#  ('02/13/23', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Their investigation did not fix an error on your report', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'GA', '30080', 'Consent provided', 'Web', '02/13/23', 'Closed with non-monetary relief', 'Yes', 6567145),
#  ('06/24/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Information belongs to someone else', 'Experian Information Solutions Inc.', 'GA', '30157', 'Other', 'Web', '06/24/22', 'Closed with non-monetary relief', 'Yes', 5706132),
#  ('02/09/23', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Information belongs to someone else', 'EQUIFAX, INC.', 'IL', '60619', 'Consent provided', 'Web', '02/09/23', 'Closed with explanation', 'Yes', 6551796),
#  ('05/17/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Other personal consumer report', 'Improper use of your report', 'Reporting company used your report improperly', 'Experian Information Solutions Inc.', 'PA', '19151', 'Consent provided', 'Web', '05/17/22', 'Closed with non-monetary relief', 'Yes', 5570121),
#  ('05/15/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'MI', '48206', 'Consent provided', 'Web', '05/15/22', 'Closed with explanation', 'Yes', 5564035),
#  ('05/17/22', 'Debt collection', 'I do not know', 'Communication tactics', 'Frequent or repeated calls', 'PORTFOLIO RECOVERY ASSOCIATES INC', 'NY', '11738', 'Consent not provided', 'Web', '05/17/22', 'Closed with non-monetary relief', 'Yes', 5570494),
#  ('05/15/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Their investigation did not fix an error on your report', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'VA', '23238', 'Consent provided', 'Web', '05/19/22', 'Closed with non-monetary relief', 'Yes', 5562715),
#  ('09/26/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Information belongs to someone else', 'Experian Information Solutions Inc.', 'NY', '11210', 'Consent not provided', 'Web', '09/26/22', 'Closed with explanation', 'Yes', 6021628),
#  ('02/13/23', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Their investigation did not fix an error on your report', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'MD', '20785', 'Consent not provided', 'Web', '02/13/23', 'Closed with non-monetary relief', 'Yes', 6567317),
#  ('03/29/23', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Personal information incorrect', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'TN', '38119', 'None', 'Web', '03/29/23', 'In progress', 'Yes', 6760136),
#  ('04/07/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'Experian Information Solutions Inc.', 'WA', '98444', 'Consent provided', 'Web', '04/08/22', 'Closed with explanation', 'Yes', 5417656),
#  ('05/17/22', 'Debt collection', 'Other debt', 'Attempts to collect debt not owed', 'Debt was paid', 'STERLING JEWELERS, INC.', 'VA', '23320', 'Consent provided', 'Web', '05/17/22', 'Closed with explanation', 'Yes', 5570466),
#  ('09/14/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'AZ', '85048', 'Consent provided', 'Web', '09/14/22', 'Closed with non-monetary relief', 'Yes', 5976962),
#  ('04/07/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'Experian Information Solutions Inc.', 'MI', '48910', 'Consent not provided', 'Web', '04/07/22', 'Closed with explanation', 'Yes', 5420526),
#  ('05/15/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Account information incorrect', 'Experian Information Solutions Inc.', 'FL', '32811', 'Consent provided', 'Web', '05/15/22', 'Closed with non-monetary relief', 'Yes', 5563978),
#  ('02/13/23', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Unable to get your credit report or credit score', 'Other problem getting your report or credit score', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'NC', '28304', 'Consent provided', 'Web', '02/13/23', 'Closed with non-monetary relief', 'Yes', 6567938),
#  ('05/16/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', "Credit inquiries on your report that you don't recognize", 'First Federal Credit Control, Inc.', 'FL', '34748', 'Consent not provided', 'Web', '05/16/22', 'Closed with explanation', 'Yes', 5564556),
#  ('09/14/22', 'Credit card or prepaid card', 'General-purpose credit card or charge card', 'Fees or interest', 'Charged too much interest', 'AMERICAN EXPRESS COMPANY', 'NY', '10280', 'Consent provided', 'Web', '09/14/22', 'Closed with monetary relief', 'Yes', 5976875),
#  ('04/07/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'Experian Information Solutions Inc.', 'NY', '10456', 'Consent provided', 'Web', '04/07/22', 'Closed with explanation', 'Yes', 5420755),
#  ('02/24/23', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Information belongs to someone else', 'Experian Information Solutions Inc.', 'WY', '82301', 'None', 'Web', '02/24/23', 'In progress', 'Yes', 6606382),
#  ('04/08/22', 'Debt collection', 'I do not know', 'Attempts to collect debt not owed', 'Debt is not yours', 'Experian Information Solutions Inc.', 'MD', '21224', 'Consent provided', 'Web', '04/08/22', 'Closed with explanation', 'Yes', 5421069),
#  ('04/07/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Account information incorrect', 'EQUIFAX, INC.', 'GA', '30022', 'Consent not provided', 'Web', '04/07/22', 'Closed with explanation', 'Yes', 5420469),
#  ('10/26/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Incorrect information on your report', 'Information belongs to someone else', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'GA', '30517', None, 'Postal mail', '10/26/22', 'Closed with non-monetary relief', 'Yes', 6134447),
#  ('05/16/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'TRANSUNION INTERMEDIATE HOLDINGS, INC.', 'MI', '48223', 'Consent provided', 'Web', '05/16/22', 'Closed with non-monetary relief', 'Yes', 5564257),
#  ('05/15/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Their investigation did not fix an error on your report', 'Experian Information Solutions Inc.', 'NC', '28262', 'Consent not provided', 'Web', '05/15/22', 'Closed with explanation', 'Yes', 5562666),
#  ('02/15/23', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Their investigation did not fix an error on your report', 'Experian Information Solutions Inc.', 'AL', '36701', 'Consent not provided', 'Web', '02/15/23', 'Closed with explanation', 'Yes', 6571605),
#  ('05/15/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'Experian Information Solutions Inc.', 'TX', '78840', 'Consent provided', 'Web', '05/15/22', 'Closed with explanation', 'Yes', 5563834),
#  ('05/15/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', "Problem with a credit reporting company's investigation into an existing problem", 'Problem with personal statement of dispute', 'Experian Information Solutions Inc.', 'MS', '39759', 'Consent provided', 'Web', '05/15/22', 'Closed with non-monetary relief', 'Yes', 5563800),
#  ('05/15/22', 'Credit reporting, credit repair services, or other personal consumer reports', 'Credit reporting', 'Improper use of your report', 'Reporting company used your report improperly', 'Experian Information Solutions Inc.', 'NY', '11221', 'Consent not provided', 'Web', '05/15/22', 'Closed with non-monetary relief', 'Yes', 5563771),
#  ...]
